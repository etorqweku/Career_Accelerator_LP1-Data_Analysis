# %% [markdown]
# <a href="https://colab.research.google.com/github/eaedk/Machine-Learning-Tutorials/blob/main/DataAnalysis_Step_By_Step_Guide.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Title
# ### Indian Startup Ecosystem Analysis

# %% [markdown]
# # Intro
# ## General
#
# ### Objective
#
# The objective of this project is to explore and find insights from the data on funding to Startups in India from **2018 to 2021**, and advise a team on thier next step as the try to venture in the Indian startup ecosystem.
#
# ### Hypothesis
# **Null Hypothesis** : Funding to startup is centralized around a few locations and sectors
#
# **Alternate Hypothesis** : Funding to startup is spred across different locations and sectors
#
# ### Research Questions
#
#
# Which Industry received the highest amount of funding?
#
# Which industry received the lowest amount of funding?
#
# Which location recorded the highest amount of funding received?
#
# What is the average amount of funding received in top ten sectors?
#
# How many companies received funding in each year?
#
# Which company received the highest amount of funds?
#
# Which company received the lowest amount of funds ?
#
# ## Notebook overview
#
# This notebook is a guide to start practicing Data Analysis.

# %% [markdown]
# # Setup

# %% [markdown]
# ## Installation
# Here is the section to install all the packages/libraries that will be needed to tackle the challlenge.

# %%
# !pip install -q <lib_001> <lib_002> ...

# %% [markdown]
# ## Importation
# Here is the section to import all the packages/libraries that will be used through this notebook.

# %%
# Data handling
import pandas as pd
import numpy as np 
import datetime as dt

# Vizualisation (Matplotlib, Plotly, Seaborn, etc. )
import seaborn as sns
import matplotlib.pyplot as plt

# EDA (pandas-profiling, etc. )
...

# Feature Processing (Scikit-learn processing, etc. )
...

# Machine Learning (Scikit-learn Estimators, Catboost, LightGBM, etc. )
...

# Hyperparameters Fine-tuning (Scikit-learn hp search, cross-validation, etc. )
...

# Other packages
import os
#from forex_python.converter import CurrencyRates

# %% [markdown]
# # Data Loading
# Here is the section to load the datasets (train, eval, test) and the additional files

# %%
# For CSV, use pandas.read_csv
data_2018=pd.read_csv('../data/startup_funding2018.csv')
data_2019=pd.read_csv('../data/startup_funding2019.csv')
data_2020=pd.read_csv('../data/startup_funding2020.csv')
data_2021=pd.read_csv('../data/startup_funding2021.csv')

# %% [markdown]
# # Exploratory Data Analysis: EDA
# Here is the section to **inspect** the datasets in depth, **present** it, make **hypotheses** and **think** the *cleaning, processing and features creation*.

# %% [markdown]
# ## Cleaning 2018 data

# %%
data_2018.head()
# Out:
#       Company Name                                           Industry  \
# 0  TheCollegeFever  Brand Marketing, Event Promotion, Marketing, S...
# 1  Happy Cow Dairy                               Agriculture, Farming
# 2       MyLoanCare   Credit, Financial Services, Lending, Marketplace
# 3      PayMe India                        Financial Services, FinTech
# 4         Eunimart                 E-Commerce Platforms, Retail, SaaS
#
#   Round/Series       Amount                          Location  \
# 0         Seed       250000       Bangalore, Karnataka, India
# 1         Seed  ₹40,000,000        Mumbai, Maharashtra, India
# 2     Series A  ₹65,000,000           Gurgaon, Haryana, India
# 3        Angel      2000000       Noida, Uttar Pradesh, India
# 4         Seed            —  Hyderabad, Andhra Pradesh, India
#
#                                        About Company
# 0  TheCollegeFever is a hub for fun, fiesta and f...
# 1  A startup which aggregates milk from dairy far...
# 2          Leading Online Loans Marketplace in India
# 3  PayMe India is an innovative FinTech organizat...
# 4  Eunimart is a one stop solution for merchants ...

# %%
data_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526 entries, 0 to 525
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company Name   526 non-null    object
#  1   Industry       526 non-null    object
#  2   Round/Series   526 non-null    object
#  3   Amount         526 non-null    object
#  4   Location       526 non-null    object
#  5   About Company  526 non-null    object
# dtypes: object(6)
# memory usage: 24.8+ KB

# %%
# maintianing first word before comma in the industry column
data_2018['Industry'] = data_2018['Industry'].apply(str)
data_2018['Industry'] = data_2018['Industry'].str.split(',').str[0]
data_2018['Industry'] = data_2018['Industry'].replace("'","",regex=True)

# %%
data_2018['Industry']
# Out:
# 0             Brand Marketing
# 1                 Agriculture
# 2                      Credit
# 3          Financial Services
# 4        E-Commerce Platforms
#                 ...
# 521                       B2B
# 522                   Tourism
# 523         Food and Beverage
# 524    Information Technology
# 525             Biotechnology
# Name: Industry, Length: 526, dtype: object

# %%
# maintianing first word before comma in the location column
data_2018['Location'] = data_2018['Location'].apply(str)
data_2018['Location'] = data_2018['Location'].str.split(',').str[0]
data_2018['Location'] = data_2018['Location'].replace("'","",regex=True)

# %%
data_2018['Location']
# Out:
# 0      Bangalore
# 1         Mumbai
# 2        Gurgaon
# 3          Noida
# 4      Hyderabad
#          ...
# 521    Bangalore
# 522      Haryana
# 523       Mumbai
# 524       Mumbai
# 525      Chennai
# Name: Location, Length: 526, dtype: object

# %%
data_2018['Amount']
# Out:
# 0           250000
# 1      ₹40,000,000
# 2      ₹65,000,000
# 3          2000000
# 4                —
#           ...
# 521      225000000
# 522              —
# 523           7500
# 524    ₹35,000,000
# 525       35000000
# Name: Amount, Length: 526, dtype: object

# %%
# Cleaning the Amounts column
## Removing the commas and dashes from the Amounts
data_2018['Amount'] = data_2018['Amount'].apply(str)
data_2018['Amount'].replace(",", "", inplace = True, regex=True)
data_2018['Amount'].replace("—", 0, inplace = True, regex=True)
data_2018['Amount'].replace("$", "", inplace = True, regex=True)

# %%
## Creating temporary columns to help with the conversion of INR to USD
data_2018['INR Amount'] = data_2018['Amount'].str.rsplit('₹', n = 2).str[1]
data_2018['INR Amount'] = data_2018['INR Amount'].apply(float).fillna(0)
data_2018['USD Amount'] = data_2018['INR Amount'] * 0.0146
data_2018['USD Amount'] = data_2018['USD Amount'].replace(0, np.nan)
data_2018['USD Amount'] = data_2018['USD Amount'].fillna(data_2018['Amount'])
data_2018['USD Amount'] = data_2018['USD Amount'].replace("$", "", regex=True)
data_2018["Amount"] = data_2018["USD Amount"]
data_2018["Amount"] = data_2018["Amount"].apply(lambda x: float(str(x).replace("$","")))
data_2018["Amount"] = data_2018["Amount"].replace(0, np.nan)

# %%
# Dropping the temporary columns
data_2018.drop(columns = ["INR Amount", "USD Amount"], inplace = True)

# %%
data_2018 = data_2018.rename(columns =  {'Company Name':'Company/Brand', 'Industry':'Sector', 'Location':'HeadQuarter','Round/Series':'Stage', 'About Company':'What it does','Amount':'Amount($)'} )

# %%
data_2018
# Out:
#          Company/Brand                  Sector     Stage    Amount($)  \
# 0      TheCollegeFever         Brand Marketing      Seed     250000.0
# 1      Happy Cow Dairy             Agriculture      Seed     584000.0
# 2           MyLoanCare                  Credit  Series A     949000.0
# 3          PayMe India      Financial Services     Angel    2000000.0
# 4             Eunimart    E-Commerce Platforms      Seed          NaN
# ..                 ...                     ...       ...          ...
# 521              Udaan                     B2B  Series C  225000000.0
# 522  Happyeasygo Group                 Tourism  Series A          NaN
# 523             Mombay       Food and Beverage      Seed       7500.0
# 524         Droni Tech  Information Technology      Seed     511000.0
# 525            Netmeds           Biotechnology  Series C   35000000.0
#
#     HeadQuarter                                       What it does
# 0     Bangalore  TheCollegeFever is a hub for fun, fiesta and f...
# 1        Mumbai  A startup which aggregates milk from dairy far...
# 2       Gurgaon          Leading Online Loans Marketplace in India
# 3         Noida  PayMe India is an innovative FinTech organizat...
# 4     Hyderabad  Eunimart is a one stop solution for merchants ...
# ..          ...                                                ...
# 521   Bangalore  Udaan is a B2B trade platform, designed specif...
# 522     Haryana            HappyEasyGo is an online travel domain.
# 523      Mumbai  Mombay is a unique opportunity for housewives ...
# 524      Mumbai  Droni Tech manufacture UAVs and develop softwa...
# 525     Chennai       Welcome to India's most convenient pharmacy!
#
# [526 rows x 6 columns]

# %%
#inspecting stage column
data_2018['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', 'Undisclosed',
#        'https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',
#        'Series D', 'Secondary Market', 'Post-IPO Equity',
#        'Non-equity Assistance', 'Funding Round'], dtype=object)

# %%
data_2018['Stage']=data_2018['Stage'].replace('https://docs.google.com/spreadsheets/d/1x9ziNeaz6auNChIHnMI8U6kS7knTr3byy_YBGfQaoUA/edit#gid=1861303593',np.nan)

# %%
data_2018['Stage']=data_2018['Stage'].replace('Undisclosed',np.nan)

# %%
data_2018['Stage'].unique()
# Out:
# array(['Seed', 'Series A', 'Angel', 'Series B', 'Pre-Seed',
#        'Private Equity', 'Venture - Series Unknown', 'Grant',
#        'Debt Financing', 'Post-IPO Debt', 'Series H', 'Series C',
#        'Series E', 'Corporate Round', nan, 'Series D', 'Secondary Market',
#        'Post-IPO Equity', 'Non-equity Assistance', 'Funding Round'],
#       dtype=object)

# %%
data_2018[data_2018['Stage']=='Venture - Series Unknown']
# Out:
#                                       Company/Brand              Sector  \
# 94                                 Rays Power Infra              Energy
# 106                                 Vivriti Capital  Financial Services
# 118                            SEDEMAC Mechatronics          Automotive
# 119                                     MadGuy Labs          E-Learning
# 131                                         Wakefit       Manufacturing
# 132                                   Hero Electric       Manufacturing
# 138                                       Wow Venue              Events
# 143                                     MyNewCar.in          Automotive
# 152                                      Shopkirana          E-Commerce
# 153                                     Fric Bergen                   —
# 160                                      ION Energy              Energy
# 349  Wicked Ride Adventure Services Private Limited          Automotive
# 358                                The Souled Store             Fashion
# 383                                        Billdesk             Finance
# 391                                          DRIVEU              Rental
# 397                                   WalMart India              Retail
# 408                                        Lucideus          Consulting
# 411                                Sukkhi Jewellery             Fashion
# 419                                      Healthkart          E-Commerce
# 427                                       RAHI Care         Health Care
# 441                                 Veritas Finance  Financial Services
# 443                                          GoZefo            Computer
# 447                                Lavelle Networks     Cloud Computing
# 453                                       InnerChef             Cooking
# 457                                           Origo                   —
# 460                                         Spoofin               Music
# 464                                   Stanza Living         Hospitality
# 469                              Satya MicroCapital             Finance
# 472                                       Sequretek                   —
# 474                                           Qbera             Finance
# 480                                          Togedr                   —
# 488                                          GoBolt           Logistics
# 492                                             Ola                Apps
# 496                                            Myra                Apps
# 503  Belstar Investment and Finance Private Limited  Financial Services
# 504                                         Naaptol          E-Commerce
# 518                                      Cleardekho             Eyewear
#
#                         Stage   Amount($) HeadQuarter  \
# 94   Venture - Series Unknown  29200000.0      Jaipur
# 106  Venture - Series Unknown  28500000.0     Chennai
# 118  Venture - Series Unknown         NaN      Mumbai
# 119  Venture - Series Unknown    150000.0   Hyderabad
# 131  Venture - Series Unknown   9490000.0   Bangalore
# 132  Venture - Series Unknown  23360000.0   New Delhi
# 138  Venture - Series Unknown   1500000.0      Mumbai
# 143  Venture - Series Unknown   1000000.0     Gurgaon
# 152  Venture - Series Unknown   2000000.0      Indore
# 153  Venture - Series Unknown         NaN       Alwar
# 160  Venture - Series Unknown   1041000.0      Mumbai
# 349  Venture - Series Unknown  10000000.0   Bangalore
# 358  Venture - Series Unknown   3000000.0      Mumbai
# 383  Venture - Series Unknown         NaN   Ahmedabad
# 391  Venture - Series Unknown   1022000.0   Bengaluru
# 397  Venture - Series Unknown  37680000.0     Gurgaon
# 408  Venture - Series Unknown   5000000.0   New Delhi
# 411  Venture - Series Unknown   7446000.0      Mumbai
# 419  Venture - Series Unknown  10000000.0     Gurgaon
# 427  Venture - Series Unknown         NaN  Chandigarh
# 441  Venture - Series Unknown  30000000.0      Guindy
# 443  Venture - Series Unknown   3066000.0   Bangalore
# 447  Venture - Series Unknown    292000.0   Bengaluru
# 453  Venture - Series Unknown   1760000.0     Gurgaon
# 457  Venture - Series Unknown  11680000.0     Gurgaon
# 460  Venture - Series Unknown         NaN   New Delhi
# 464  Venture - Series Unknown  10658000.0   New Delhi
# 469  Venture - Series Unknown   5840000.0   New Delhi
# 472  Venture - Series Unknown   3700000.0      Mumbai
# 474  Venture - Series Unknown   2044000.0   Bangalore
# 480  Venture - Series Unknown         NaN     Gurgaon
# 488  Venture - Series Unknown   5840000.0   New Delhi
# 492  Venture - Series Unknown  50000000.0  Kormangala
# 496  Venture - Series Unknown    127750.0   Bangalore
# 503  Venture - Series Unknown  28000000.0     Chennai
# 504  Venture - Series Unknown  15000000.0      Mumbai
# 518  Venture - Series Unknown         NaN   Ghaziabad
#
#                                           What it does
# 94   Rays Power Infra is a leading integrated Solar...
# 106  Vivriti Capital is an online platform for inst...
# 118  SEDEMAC Mechatronics is technology company tha...
# 119        MadGuy Labs is a Online Test-prep Platform.
# 131  Wakefitkart is a mattress manufacturing compan...
# 132  Hero Electric, a 100% subsidiary of the Hero G...
# 138                   Wow Venue is an online platform.
# 143  MyNewCar.in offers new cars at best price with...
# 152  Shopkirana connects brands and traditional ret...
# 153  Fric Bergen is a leader in the specialty food ...
# 160  A stealth startup building a layer of infrastr...
# 349                Peer-to-Peer motor vehicles sharing
# 358  The Souled Store bring to you awesome t-shirts...
# 383  BillDesk, a property of IndiaIdeas.com Ltd. wa...
# 391  DriveU is a convenient and a quick way of gett...
# 397  Wal-Mart India Private Limited is a wholly own...
# 408  Lucideus is a cybersecurity company that offer...
# 411  Sukkhi Jewellery is a Contemporary fashion jew...
# 419    The one stop shop for health, fitness & beauty.
# 427                RAHI Care is a Health Care company.
# 441  Veritas Finance has been promoted with a prima...
# 443  Startup working on a white space in the eComme...
# 447  Lavelle Networks provides Software Defined WAN...
# 453  InnerChef is an online food discovery and deli...
# 457  Origo Commodities, a complete post-harvest man...
# 460  A social networking app that lets you create a...
# 464  Stanza Living is a co-living platform created ...
# 469     New Delhi-based non-banking financial company.
# 472            Sequretek is a cyber security start-up.
# 474  Qbera is a managed marketplace for unsecured p...
# 480  Togedr is an activity discovery & booking plat...
# 488                  Delhi-based logistics technology.
# 492  Ola is a mobile app that brings together cab d...
# 496  Myra is a unique solution of technology and op...
# 503  Belstar Investment and Finance Private Limited...
# 504  Koku Gamer is an online platform that offers g...
# 518    Uttar Pradesh based online eyewear marketplace.

# %%
data_2018['Stage']=data_2018['Stage'].replace('Venture - Series Unknown',np.nan)

# %%
##sector
data_2018['Sector'].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        '—', 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
#        'Consumer Applications', 'Mobile', 'Advertising', 'Marketplace',
#        'Aerospace', 'Home Decor', 'Energy', 'Digital Marketing',
#        'Creative Agency', 'Consumer Lending', 'Health Diagnostics',
#        'Banking', 'Embedded Systems', 'Beauty', 'AgTech', 'Credit Cards',
#        'Software', 'Manufacturing', 'Hospital', 'Events', '3D Printing',
#        'Digital Entertainment', 'Funding Platform', 'Classifieds',
#        'Enterprise Resource Planning (ERP)', 'Audio', 'Government',
#        'Digital Media', 'Business Intelligence', 'Children', 'Rental',
#        'Travel', 'Wealth Management', 'Veterinary', 'Tourism',
#        'Consumer Electronics', 'Analytics', 'Facilities Support Services',
#        'Medical', 'Music Streaming', 'Retail', 'Business Development',
#        'Human Resources', 'Customer Service', 'Training',
#        'Dietary Supplements', 'Collaboration', 'Nanotechnology',
#        'File Sharing', 'Crowdfunding', 'Catering', 'Computer', 'Android',
#        'Delivery', 'Environmental Consulting', 'Commercial Real Estate',
#        'Delivery Service', 'Basketball', 'Fraud Detection',
#        'Cryptocurrency', 'Wedding', 'Crowdsourcing', 'Farming',
#        'Business Travel', 'Career Planning', 'Medical Device',
#        'Alternative Medicine', 'Dental', 'CleanTech', 'Marketing',
#        'Commercial', 'Continuing Education', 'Smart Cities',
#        'Social Media', 'Biopharma', 'Child Care', 'Health Insurance',
#        'Gaming', 'Search Engine', 'Battery', 'Cosmetics', 'eSports',
#        'Reading Apps', 'Electric Vehicle', 'Packaging Services',
#        'Last Mile Transportation', 'Cooking', 'FinTech', 'Online Games',
#        'Online Portals', 'Music', 'News', 'Industrial', 'Dating',
#        'Fantasy Sports', 'Eyewear'], dtype=object)

# %%
data_2018['Sector']= data_2018['Sector'].replace('—',np.nan)

# %%
#Headquarters
data_2018['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad',
#        'Bengaluru', 'Kalkaji', 'Delhi', 'India', 'Hubli', 'New Delhi',
#        'Chennai', 'Mohali', 'Kolkata', 'Pune', 'Jodhpur', 'Kanpur',
#        'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin', 'Faridabad', 'Jaipur',
#        'Kota', 'Anand', 'Bangalore City', 'Belgaum', 'Thane', 'Margão',
#        'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow'],
#       dtype=object)

# %%
data_2018['Funding Year']=2018
data_2018
# Out:
#          Company/Brand                  Sector     Stage    Amount($)  \
# 0      TheCollegeFever         Brand Marketing      Seed     250000.0
# 1      Happy Cow Dairy             Agriculture      Seed     584000.0
# 2           MyLoanCare                  Credit  Series A     949000.0
# 3          PayMe India      Financial Services     Angel    2000000.0
# 4             Eunimart    E-Commerce Platforms      Seed          NaN
# ..                 ...                     ...       ...          ...
# 521              Udaan                     B2B  Series C  225000000.0
# 522  Happyeasygo Group                 Tourism  Series A          NaN
# 523             Mombay       Food and Beverage      Seed       7500.0
# 524         Droni Tech  Information Technology      Seed     511000.0
# 525            Netmeds           Biotechnology  Series C   35000000.0
#
#     HeadQuarter                                       What it does  \
# 0     Bangalore  TheCollegeFever is a hub for fun, fiesta and f...
# 1        Mumbai  A startup which aggregates milk from dairy far...
# 2       Gurgaon          Leading Online Loans Marketplace in India
# 3         Noida  PayMe India is an innovative FinTech organizat...
# 4     Hyderabad  Eunimart is a one stop solution for merchants ...
# ..          ...                                                ...
# 521   Bangalore  Udaan is a B2B trade platform, designed specif...
# 522     Haryana            HappyEasyGo is an online travel domain.
# 523      Mumbai  Mombay is a unique opportunity for housewives ...
# 524      Mumbai  Droni Tech manufacture UAVs and develop softwa...
# 525     Chennai       Welcome to India's most convenient pharmacy!
#
#      Funding Year
# 0            2018
# 1            2018
# 2            2018
# 3            2018
# 4            2018
# ..            ...
# 521          2018
# 522          2018
# 523          2018
# 524          2018
# 525          2018
#
# [526 rows x 7 columns]

# %% [markdown]
# ## Cleaning 2019 data

# %%
data_2019
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# ..                                                ...
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders  \
# 0                                  Shantanu Deshpande
# 1               Adamas Belva Syah Devara, Iman Usman.
# 2                                       Jatin Solanki
# 3                        Srikanth Iyer, Rama Harinath
# 4                              Narayana Reddy Punyala
# ..                                                ...
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor     Amount($)  \
# 0                                Sixth Sense Ventures    $6,300,000
# 1                                    General Atlantic  $150,000,000
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   $28,000,000
# 3   Evolvence India Fund (EIF), Pidilite Group, FJ...   $30,000,000
# 4            Innovation in Food and Agriculture (IFA)    $6,000,000
# ..                                                ...           ...
# 84  Tiger Global, Nexus Venture Partners, Accel Pa...   $20,000,000
# 85  MyPreferred Transformation, Avendus Finance, S...  $693,000,000
# 86                                    Sequoia Capital    $5,000,000
# 87  Norwest Venture Partners, General Catalyst, Fu...   $50,000,000
# 88     TPG, Norwest Venture Partners, Evolvence India   $33,000,000
#
#             Stage
# 0             NaN
# 1        Series C
# 2   Fresh funding
# 3        Series D
# 4             NaN
# ..            ...
# 84       Series A
# 85            NaN
# 86       Series B
# 87            NaN
# 88            NaN
#
# [89 rows x 9 columns]

# %% [markdown]
# ### Inspect individual columns

# %%
#founded
data_2019['Founded'].unique()
# Out:
# array([  nan, 2014., 2004., 2013., 2010., 2018., 2019., 2017., 2011.,
#        2015., 2016., 2012., 2008.])

# %%
#headquarters
data_2019['HeadQuarter'].unique()
# Out:
# array([nan, 'Mumbai', 'Chennai', 'Telangana', 'Pune', 'Bangalore',
#        'Noida', 'Delhi', 'Ahmedabad', 'Gurugram', 'Haryana', 'Chandigarh',
#        'Jaipur', 'New Delhi', 'Surat', 'Uttar pradesh', 'Hyderabad',
#        'Rajasthan'], dtype=object)

# %%
#sector
data_2019['Sector'].unique()
# Out:
# array(['Ecommerce', 'Edtech', 'Interior design', 'AgriTech', 'Technology',
#        'SaaS', 'AI & Tech', 'E-commerce', 'E-commerce & AR', 'Fintech',
#        'HR tech', 'Food tech', 'Health', 'Healthcare', 'Safety tech',
#        'Pharmaceutical', 'Insurance technology', 'AI', 'Foodtech', 'Food',
#        'IoT', 'E-marketplace', 'Robotics & AI', 'Logistics', 'Travel',
#        'Manufacturing', 'Food & Nutrition', 'Social Media', nan,
#        'E-Sports', 'Cosmetics', 'B2B', 'Jewellery', 'B2B Supply Chain',
#        'Games', 'Food & tech', 'Accomodation', 'Automotive tech',
#        'Legal tech', 'Mutual Funds', 'Cybersecurity', 'Automobile',
#        'Sports', 'Healthtech', 'Yoga & wellness', 'Virtual Banking',
#        'Transportation', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech', 'Hospitality',
#        'Automobile & Technology', 'Banking'], dtype=object)

# %%
data_2019['Amount($)'].unique()
# Out:
# array(['$6,300,000', '$150,000,000', '$28,000,000', '$30,000,000',
#        '$6,000,000', 'Undisclosed', '$1,000,000', '$20,000,000',
#        '$275,000,000', '$22,000,000', '$5,000,000', '$140,500',
#        '$540,000,000', '$15,000,000', '$182,700', '$12,000,000',
#        '$11,000,000', '$15,500,000', '$1,500,000', '$5,500,000',
#        '$2,500,000', '$140,000', '$230,000,000', '$49,400,000',
#        '$32,000,000', '$26,000,000', '$150,000', '$400,000', '$2,000,000',
#        '$100,000,000', '$8,000,000', '$100,000', '$50,000,000',
#        '$120,000,000', '$4,000,000', '$6,800,000', '$36,000,000',
#        '$5,700,000', '$25,000,000', '$600,000', '$70,000,000',
#        '$60,000,000', '$220,000', '$2,800,000', '$2,100,000',
#        '$7,000,000', '$311,000,000', '$4,800,000', '$693,000,000',
#        '$33,000,000'], dtype=object)

# %%
#remove comas, dashes from the amounts in the data frame
data_2019["Amount($)"] = data_2019["Amount($)"].apply(str)
data_2019["Amount($)"].replace(",","", inplace = True, regex=True)
data_2019["Amount($)"].replace("Undisclosed", np.nan, inplace = True, regex=True)
data_2019["Amount($)"] = data_2019["Amount($)"].apply(lambda x: float(str(x).replace("$","")))
data_2019["Founded"].replace("nan", np.nan, inplace = True, regex=True)
data_2019.head()
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 0  Bombay Shaving      NaN         NaN        Ecommerce
# 1       Ruangguru   2014.0      Mumbai           Edtech
# 2        Eduisfun      NaN      Mumbai           Edtech
# 3        HomeLane   2014.0     Chennai  Interior design
# 4        Nu Genes   2004.0   Telangana         AgriTech
#
#                                         What it does  \
# 0         Provides a range of male grooming products
# 1  A learning platform that provides topic-based ...
# 2            It aims to make learning fun via games.
# 3              Provides interior designing solutions
# 4  It is a seed company engaged in production, pr...
#
#                                 Founders  \
# 0                     Shantanu Deshpande
# 1  Adamas Belva Syah Devara, Iman Usman.
# 2                          Jatin Solanki
# 3           Srikanth Iyer, Rama Harinath
# 4                 Narayana Reddy Punyala
#
#                                             Investor    Amount($)  \
# 0                               Sixth Sense Ventures    6300000.0
# 1                                   General Atlantic  150000000.0
# 2     Deepak Parekh, Amitabh Bachchan, Piyush Pandey   28000000.0
# 3  Evolvence India Fund (EIF), Pidilite Group, FJ...   30000000.0
# 4           Innovation in Food and Agriculture (IFA)    6000000.0
#
#            Stage
# 0            NaN
# 1       Series C
# 2  Fresh funding
# 3       Series D
# 4            NaN

# %%
data_2019['Funding Year']=2019
data_2019
# Out:
#       Company/Brand  Founded HeadQuarter                   Sector  \
# 0    Bombay Shaving      NaN         NaN                Ecommerce
# 1         Ruangguru   2014.0      Mumbai                   Edtech
# 2          Eduisfun      NaN      Mumbai                   Edtech
# 3          HomeLane   2014.0     Chennai          Interior design
# 4          Nu Genes   2004.0   Telangana                 AgriTech
# ..              ...      ...         ...                      ...
# 84     Infra.Market      NaN      Mumbai                Infratech
# 85              Oyo   2013.0    Gurugram              Hospitality
# 86       GoMechanic   2016.0       Delhi  Automobile & Technology
# 87           Spinny   2015.0       Delhi               Automobile
# 88  Ess Kay Fincorp      NaN   Rajasthan                  Banking
#
#                                          What it does  \
# 0          Provides a range of male grooming products
# 1   A learning platform that provides topic-based ...
# 2             It aims to make learning fun via games.
# 3               Provides interior designing solutions
# 4   It is a seed company engaged in production, pr...
# ..                                                ...
# 84  It connects client requirements to their suppl...
# 85                Provides rooms for comfortable stay
# 86  Find automobile repair and maintenance service...
# 87                                Online car retailer
# 88              Organised Non-Banking Finance Company
#
#                                              Founders  \
# 0                                  Shantanu Deshpande
# 1               Adamas Belva Syah Devara, Iman Usman.
# 2                                       Jatin Solanki
# 3                        Srikanth Iyer, Rama Harinath
# 4                              Narayana Reddy Punyala
# ..                                                ...
# 84                    Aaditya Sharda, Souvik Sengupta
# 85                                     Ritesh Agarwal
# 86  Amit Bhasin, Kushal Karwa, Nitin Rana, Rishabh...
# 87  Niraj Singh, Ramanshu Mahaur, Ganesh Pawar, Mo...
# 88                                     Rajendra Setia
#
#                                              Investor    Amount($)  \
# 0                                Sixth Sense Ventures    6300000.0
# 1                                    General Atlantic  150000000.0
# 2      Deepak Parekh, Amitabh Bachchan, Piyush Pandey   28000000.0
# 3   Evolvence India Fund (EIF), Pidilite Group, FJ...   30000000.0
# 4            Innovation in Food and Agriculture (IFA)    6000000.0
# ..                                                ...          ...
# 84  Tiger Global, Nexus Venture Partners, Accel Pa...   20000000.0
# 85  MyPreferred Transformation, Avendus Finance, S...  693000000.0
# 86                                    Sequoia Capital    5000000.0
# 87  Norwest Venture Partners, General Catalyst, Fu...   50000000.0
# 88     TPG, Norwest Venture Partners, Evolvence India   33000000.0
#
#             Stage  Funding Year
# 0             NaN          2019
# 1        Series C          2019
# 2   Fresh funding          2019
# 3        Series D          2019
# 4             NaN          2019
# ..            ...           ...
# 84       Series A          2019
# 85            NaN          2019
# 86       Series B          2019
# 87            NaN          2019
# 88            NaN          2019
#
# [89 rows x 10 columns]

# %% [markdown]
# ## Cleaning 2020 data
# * Inspect indiviual columns and fix errors in data set
# * Drop **Unnamed: 9** column

# %%
data_2020['Unnamed: 9'].unique()
# Out:
# array([nan, 'Pre-Seed', 'Seed Round'], dtype=object)

# %%
data_2020.loc[data_2020['Unnamed: 9']=='Seed Round']
# Out:
#     Company/Brand Founded HeadQuarter   Sector             What it does  \
# 613       goDutch     NaN      Mumbai  Fintech  Group Payments platform
#
#                                     Founders  \
# 613  Aniruddh Singh, Riyaz Khan, Sagar Sheth
#
#                                               Investor   Amount($)  \
# 613  Matrix India, Y Combinator, Global Founders Ca...  $1,700,000
#
#           Stage  Unnamed: 9
# 613  Seed Round  Seed Round

# %%
data_2020.loc[data_2020['Unnamed: 9']=='Pre-Seed']
# Out:
#     Company/Brand Founded HeadQuarter   Sector  \
# 611        Walrus    2019   Bangalore  Fintech
#
#                                           What it does  \
# 611  It provides banking solutions for teens and yo...
#
#                                             Founders        Investor  \
# 611  Bhagaban Behera, Sriharsha Shetty, Nakul Kelkar  Better Capital
#
#        Amount($)     Stage Unnamed: 9
# 611  Undisclosed  Pre-Seed   Pre-Seed

# %%
data_2020=data_2020.drop('Unnamed: 9', axis=1)

# %%
#founded column
data_2020['Founded'].unique()
# Out:
# array(['2019', '2018', '2020', '2016', '2008', '2015', '2017', '2014',
#        '1998', '2007', '2011', '1982', '2013', '2009', '2012', '1995',
#        '2010', '2006', '1978', nan, '1999', '1994', '2005', '1973', '-',
#        '2002', '2004', '2001'], dtype=object)

# %%
#replace '-' with NaN
data_2020["Founded"].replace("-", np.nan, inplace = True, regex=True)

# %%
#headquarters
data_2020['HeadQuarter'].unique()
# Out:
# array(['Chennai', 'Bangalore', 'Pune', 'New Delhi', 'Indore', 'Hyderabad',
#        'Gurgaon', 'Belgaum', 'Noida', 'Mumbai', 'Andheri', 'Jaipur',
#        'Ahmedabad', 'Kolkata', 'Tirunelveli, Tamilnadu', 'Thane', nan,
#        'Singapore', 'Gurugram', 'Gujarat', 'Haryana', 'Kerala', 'Jodhpur',
#        'Jaipur, Rajastan', 'Delhi', 'Frisco, Texas, United States',
#        'California', 'Dhingsara, Haryana', 'New York, United States',
#        'Patna', 'San Francisco, California, United States',
#        'San Francisco, United States', 'San Ramon, California',
#        'Paris, Ile-de-France, France', 'Plano, Texas, United States',
#        'Sydney', 'San Francisco Bay Area, Silicon Valley, West Coast',
#        'Bangaldesh', 'London, England, United Kingdom',
#        'Sydney, New South Wales, Australia', 'Milano, Lombardia, Italy',
#        'Palmwoods, Queensland, Australia', 'France',
#        'San Francisco Bay Area, West Coast, Western US',
#        'Trivandrum, Kerala, India', 'Cochin', 'Samastipur, Bihar',
#        'Irvine, California, United States', 'Tumkur, Karnataka',
#        'Newcastle Upon Tyne, Newcastle upon Tyne, United Kingdom',
#        'Shanghai, China', 'Jiaxing, Zhejiang, China', 'Rajastan', 'Kochi',
#        'Ludhiana', 'Dehradun', 'San Franciscao', 'San Francisco',
#        'Tangerang, Jawa Barat, Indonesia', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'New York', 'Bangkok', 'Kanpur', 'Chandigarh', 'Warangal',
#        'Hyderebad', 'Odisha', 'Bihar', 'Goa', 'Tamil Nadu',
#        'Uttar Pradesh', 'Bhopal', 'Banglore', 'Coimbatore', 'Bengaluru'],
#       dtype=object)

# %%
# maintain first words using slipt by comma
data_2020['HeadQuarter'] = data_2020['HeadQuarter'].apply(str)
data_2020['HeadQuarter'] = data_2020['HeadQuarter'].str.split(',').str[0]
data_2020['HeadQuarter'] = data_2020['HeadQuarter'].replace("'","",regex=True)

# %%
#amount column
data_2020['Amount($)'].unique()
# Out:
# array(['$200,000', '$100,000', 'Undisclosed', '$400,000', '$340,000',
#        '$600,000', '$45,000,000', '$1,000,000', '$2,000,000',
#        '$1,200,000', '$660,000,000', '$120,000', '$7,500,000',
#        '$5,000,000', '$500,000', '$3,000,000', '$10,000,000',
#        '$145,000,000', '$100,000,000', nan, '$21,000,000', '$4,000,000',
#        '$20,000,000', '$560,000', '$275,000', '$4,500,000', '$15,000,000',
#        '$390,000,000', '$7,000,000', '$5,100,000', '$700,000,000',
#        '$2,300,000', '$700,000', '$19,000,000', '$9,000,000',
#        '$40,000,000', '$750,000', '$1,500,000', '$7,800,000',
#        '$50,000,000', '$80,000,000', '$30,000,000', '$1,700,000',
#        '$2,500,000', '$40,000', '$33,000,000', '$35,000,000', '$300,000',
#        '$25,000,000', '$3,500,000', '$200,000,000', '$6,000,000',
#        '$1,300,000', '$4,100,000', '$575,000', '$800,000', '$28,000,000',
#        '$18,000,000', '$3,200,000', '$900,000', '$250,000', '$4,700,000',
#        '$75,000,000', '$8,000,000', '$121,000,000', '$55,000,000',
#        '$3,300,000', '$11,000,000', '$16,000,000', '$5,400,000',
#        '$150,000,000', '$4,200,000', '$22,000,000', '$52,000,000',
#        '$1,100,000', '$118,000,000', '$1,600,000', '$18,500,000',
#        '$70,000,000,000', '$800,000,000', '$400,000,000', '$150,000',
#        '$176,000,000', '$60,000,000', '$470,000', '$240,000',
#        '$3,000,000,000', '$74,000,000', '$62,000,000', '$2,100,000',
#        '$500,000,000', '$12,500,000', '$2,200,000,000', '$5,060,000',
#        '$225,000,000', '$24,700,000', '$7,700,000', '$1,90,67,328',
#        '$51,000,000', '$115,000', '$54,000', '$20,000', '$803,146',
#        '$238,000', '$10,220,000', '$1,020,000', '$12,000,000',
#        '$13,400,000', '$170,000,000', '$2,900,000', '$543,000',
#        '$90,000,000', '$3,400,000', '$23,000,000', '$8,090,000',
#        '$1,030,000', '$5,040,000', '$360,000', '$1,400,000', '$650,000',
#        '$54,000,000', '$42,500,000', '$11,370,000', '$325,000',
#        '$410,000', '$450,000', '$682,000', '$4,050,000', '$1,050,000',
#        '$1,080,000', '$4,300,000', '$6,800,000', '$2,110,000',
#        '$887,000, $23,000,000', '$764,000', '$603,000', '$409,000',
#        '$292,000', '$286,000', '$136,000', '$800,000,000 to $850,000,000',
#        '$546,000', '$887,000', '$43,000', '$40,900', '$2,200,000',
#        '$5,660,000', '$350,000', '$110,000', '$122,000,000',
#        '$11,635,000', '$2,800,000', '$1,065,000', '$669,000',
#        '$16,076,000', '$649,600', '$6,700,000', '$220,000', '$266,500',
#        '$2,879,000', '$26,500,000', '$351,000', '$ 8,700,000',
#        '$46,761,000', '$175,000', '9.600,000', '$11,241,000', '$804,000',
#        '$1,340,000', '$467,000', '$133,000', '$3,823,000', '$934,000',
#        '$293,000', '$198,000', '$927,000', '$971,000', '$3,060,000',
#        '$1,862,000', '$232,000', '$2,888,000', '$1,328,000',
#        '$15,500,000', '$56,000,000', '$2,250,000', '$16,753,000',
#        '$3,700,000', '$1,470,000', '$530,000', '$267,000', '$3,344,000',
#        '$7,200,000', '$2,743,000', '$6,082,000', '$6,609,000',
#        '$27,700,000', '$5,940,000', '$3,964,000', '$5,500,000',
#        '$197,000', '$4,327,000', '$459,000', '$3,937,000', '$1,313,500',
#        '$229,800', '$5,305,000', '$264,000', '$1,750,000', '$5,967,000',
#        '$2,980,000', 'Undiclsosed', '$323,000', '$1,326,000',
#        '$27,000,000', '$5,200,000', '$2,530,000', '$792,000',
#        '$11,363,000', '$1,715,000', '$329,000', '$5,271,000',
#        '$8,700,000', '$3,226,000', '$5,900,000', '$44,000,000',
#        '$3,879,000', '$13,000,000', '$8,800,000', '$9,500,000',
#        '$920,000', '$35,600,000', '$9,400,000', '$790,000', '$480,000',
#        '$160,000', '$8,200,000', '$4,257,000', '$1,410,000', '$349,800',
#        '$786,000', '$2,004,000', '$123,000,000', '$248,000',
#        '$24,000,000', '$14,259,000', '$24,500,000', '$3,800,000',
#        '$18,370,000', '$68,525,000', '$4,800,000', '$1,834,000',
#        '$23,850,000', '$43,000,000', '$21,600,000', '$4,598,000',
#        '$13,137,000', '$115,000,000', '$3,900,000', '$670,000',
#        '42.23,000', '$8,500,000', '$3,148,000', '$2,600,000', '25,58,000',
#        '$4,049,500', '$10,500,000', '$6,500,000', '$43,700,000',
#        '$13,800,000', '$306,900', '$420,000', '$627,300', '$113,000,000',
#        '$32,000,000', '$110,000,000', '$1,397,000', '$448,500',
#        '$7,975,700', '$330,000', '$5,600,000', '$1,402,000',
#        '$21,500,000', '$296,000,000', '$4,900,000', '$1,402,400',
#        '$12,618,300', '$9,900,000', '$982,530', '$70,185,200',
#        '$210,000,000', '$84,000,000', '$39,000,000', '$2,700,000',
#        '$1,403,400', '$105,000,000', '$103,000,000', '$281,300',
#        '$12,700', '$25,000', '$97,500,000', '$507,000', 'Undislosed',
#        '$8,400,000', '$18,300,000', '$125,000,000', '$181,000',
#        '$280,000', '$14,700,000', '$13,200,000', '$8,043,000'],
#       dtype=object)

# %%
# remove comma and dollar sign from amounts
data_2020["Amount($)"] = data_2020["Amount($)"].apply(str)
data_2020["Amount($)"].replace(",","", inplace = True, regex=True)
data_2020["Amount($)"].replace("Undisclosed", np.nan, inplace = True, regex=True)
data_2020["Amount($)"].replace("Undiclsosed", np.nan, inplace = True, regex=True)
data_2020["Amount($)"].replace("Undislosed", np.nan, inplace = True, regex=True)
data_2020["Amount($)"].replace("nan", np.nan, inplace = True, regex=True)

data_2020["Amount($)"] = data_2020["Amount($)"].apply(lambda x:(str(x).replace("$","")))

# %%
#Replacing the amounts "887000 23000000" and 800000000 to 850000000 with their avaerage
data_2020["Amount($)"].replace("887000 23000000", "119435500.0", inplace = True, regex=True)
data_2020["Amount($)"].replace("800000000 to 850000000", "825000000.0", inplace = True, regex=True)

# %%
data_2020['Amount($)'].replace('9.600000','9600000', inplace= True,regex=True)
data_2020['Amount($)'].replace('42.23000','4223000',inplace =True, regex=True)

# %%
data_2020["Amount($)"].astype("float")
# Out:
# 0         200000.0
# 1         100000.0
# 2              NaN
# 3         400000.0
# 4         340000.0
#            ...
# 1050     1500000.0
# 1051    13200000.0
# 1052     8000000.0
# 1053     8043000.0
# 1054     9000000.0
# Name: Amount($), Length: 1055, dtype: float64

# %%
data_2020['Funding Year']=2020
data_2020
# Out:
#      Company/Brand Founded HeadQuarter              Sector  \
# 0       Aqgromalin    2019     Chennai            AgriTech
# 1         Krayonnz    2019   Bangalore              EdTech
# 2     PadCare Labs    2018        Pune  Hygiene management
# 3            NCOME    2020   New Delhi              Escrow
# 4       Gramophone    2016      Indore            AgriTech
# ...            ...     ...         ...                 ...
# 1050  Leverage Edu     NaN       Delhi              Edtech
# 1051         EpiFi     NaN         nan             Fintech
# 1052       Purplle    2012      Mumbai           Cosmetics
# 1053        Shuttl    2015       Delhi           Transport
# 1054         Pando    2017     Chennai            Logitech
#
#                                            What it does  \
# 0                          Cultivating Ideas for Profit
# 1     An academy-guardian-scholar centric ecosystem ...
# 2      Converting bio-hazardous waste to harmless waste
# 3                          Escrow-as-a-service platform
# 4     Gramophone is an AgTech platform enabling acce...
# ...                                                 ...
# 1050  AI enabled marketplace that provides career gu...
# 1051  It offers customers with a single interface fo...
# 1052         Online makeup and beauty products retailer
# 1053                    App based bus aggregator serice
# 1054            Networked logistics management software
#
#                                                Founders  \
# 0                       Prasanna Manogaran, Bharani C L
# 1                      Saurabh Dixit, Gurudutt Upadhyay
# 2                                       Ajinkya Dhariya
# 3                                         Ritesh Tiwari
# 4     Ashish Rajan Singh, Harshit Gupta, Nishant Mah...
# ...                                                 ...
# 1050                                  Akshay Chaturvedi
# 1051                    Sujith Narayanan, Sumit Gwalani
# 1052                          Manish Taneja, Rahul Dash
# 1053                      Amit Singh, Deepanshu Malviya
# 1054                     Jayakrishnan, Abhijeet Manohar
#
#                                    Investor Amount($)       Stage  \
# 0                           Angel investors    200000         NaN
# 1                           GSF Accelerator    100000    Pre-seed
# 2                            Venture Center       nan    Pre-seed
# 3       Venture Catalysts, PointOne Capital    400000         NaN
# 4       Siana Capital Management, Info Edge    340000         NaN
# ...                                     ...       ...         ...
# 1050  DSG Consumer Partners, Blume Ventures   1500000         NaN
# 1051          Sequoia India, Ribbit Capital  13200000  Seed Round
# 1052                             Verlinvest   8000000         NaN
# 1053             SIG Global India Fund LLP.   8043000    Series C
# 1054                      Chiratae Ventures   9000000    Series A
#
#       Funding Year
# 0             2020
# 1             2020
# 2             2020
# 3             2020
# 4             2020
# ...            ...
# 1050          2020
# 1051          2020
# 1052          2020
# 1053          2020
# 1054          2020
#
# [1055 rows x 10 columns]

# %% [markdown]
# ## Cleaning 2021 data
# * Inspect indiviual columns and fix errors in data set
# * Move data to thier right columns

# %%
data_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor     Amount($)  \
# 0                       BEENEXT, Entrepreneur First    $1,200,000
# 1          Unilazer Ventures, IIFL Asset Management  $120,000,000
# 2                  GSV Ventures, Westbridge Capital   $30,000,000
# 3                            CDC Group, IDG Capital   $51,000,000
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    $2,000,000
# ...                                             ...           ...
# 1204                                Endiya Partners      $3000000
# 1205                                       IIFL AMC     $20000000
# 1206                                   Owl Ventures     $55000000
# 1207               Winter Capital, ETS, Man Capital     $26000000
# 1208                 3one4 Capital, Kalaari Capital      $8000000
#
#              Stage
# 0     Pre-series A
# 1              NaN
# 2         Series D
# 3         Series C
# 4             Seed
# ...            ...
# 1204  Pre-series A
# 1205      Series D
# 1206      Series C
# 1207      Series B
# 1208      Series A
#
# [1209 rows x 9 columns]

# %%
#headquarters
data_2021['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurugram', 'New Delhi', 'Hyderabad',
#        'Jaipur', 'Ahmadabad', 'Chennai', nan,
#        'Small Towns, Andhra Pradesh', 'Goa', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Gujarat', 'Pune', 'Thane', 'Computer Games',
#        'Cochin', 'Noida', 'Chandigarh', 'Gurgaon', 'Vadodara',
#        'Food & Beverages', 'Pharmaceuticals\t#REF!', 'Gurugram\t#REF!',
#        'Kolkata', 'Ahmedabad', 'Mohali', 'Haryana', 'Indore', 'Powai',
#        'Ghaziabad', 'Nagpur', 'West Bengal', 'Patna', 'Samsitpur',
#        'Lucknow', 'Telangana', 'Silvassa', 'Thiruvananthapuram',
#        'Faridabad', 'Roorkee', 'Ambernath', 'Panchkula', 'Surat',
#        'Coimbatore', 'Andheri', 'Mangalore', 'Telugana', 'Bhubaneswar',
#        'Kottayam', 'Beijing', 'Panaji', 'Satara', 'Orissia', 'Jodhpur',
#        'New York', 'Santra', 'Mountain View, CA', 'Trivandrum',
#        'Jharkhand', 'Kanpur', 'Bhilwara', 'Guwahati',
#        'Online Media\t#REF!', 'Kochi', 'London',
#        'Information Technology & Services', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %%
#correcting data
data_2021['HeadQuarter'].replace('Gurugram\t#REF!','Gurugram',inplace =True, regex=True)

# %%
data_2021[data_2021['HeadQuarter']=='Online Media\t#REF!']
# Out:
#      Company/Brand  Founded          HeadQuarter  \
# 1100      Sochcast   2020.0  Online Media\t#REF!
#
#                                                  Sector  \
# 1100  Sochcast is an Audio experiences company that ...
#
#                                            What it does  \
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
#
#                                      Founders      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed       NaN   NaN

# %%
data_2021.loc[data_2021["HeadQuarter"] == 'Pharmaceuticals\t#REF!']
# Out:
#           Company/Brand  Founded             HeadQuarter  \
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  What it does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %%
#sector
data_2021['Sector'].unique()
# Out:
# array(['AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'LegalTech', 'Food delivery', 'Automotive',
#        'SaaS startup', 'Fantasy sports', 'Video communication',
#        'Social Media', 'Skill development', 'Rental', 'Recruitment',
#        'HealthCare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'Healthcare',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual',
#        'Financial Services', 'Industrial Automation', 'Health',
#        'Lifestyle', 'IoT', 'Banking', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B marketplace', 'Healtcare', 'Location Analytics',
#        'Media', 'Consumer Electronics', 'Tobacco', 'Deeptech',
#        'Insuretech', 'MLOps platform', 'Venture Capital', 'Pet care',
#        'Drone', 'Wholesale', 'Construction', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Hauz Khas',
#        'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.',
#        "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.",
#        'Cosmetics', 'Mobility', 'Social media', 'Real Estate',
#        'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Social commerce', 'Mobile Games', 'Food Production', 'Podcast',
#        'HeathTech', 'Battery', 'Content publishing', 'Water purification',
#        'Content commerce', 'Innovation Management', 'Software company',
#        'Automation', 'Food Industry', 'Celebrity Engagement',
#        'Trading platform', 'Personal Care', 'Cannabis startup',
#        'Blogging', 'Consulting', 'BioTechnology', 'B2B Marketplace',
#        'Health care', 'Social audio', 'Fashion and lifestyle',
#        'Delivery service', 'B2B Manufacturing', 'Home Decor', 'Solar',
#        'TaaS startup', 'EV startup', 'HR Tech', 'Blockchain startup',
#        'Food and Beverages', 'Beverages', 'Manufacturing startup',
#        'Cryptocurrency', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'SpaceTech', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'Software', 'Nutrition', 'D2C startup', 'Innovation management',
#        'Community platform', 'Venture capitalist', 'Networking',
#        'Commercial Real Estate', 'AR startup', 'Consumer service',
#        'Consumer goods', 'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Rental space', 'Bike Rental',
#        'Beauty products', 'Tourism', 'FemTech', 'Cultural', 'Co-working',
#        'InsureTech', 'Supply chain platform', 'Social platform',
#        'CleanTech', 'Real estate', 'AI company', 'Sports startup',
#        'Matrimony', 'Crypto', 'Clothing', 'Analytics', 'Finance',
#        'IoT platform', 'Commerce', 'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy', 'EV',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Education',
#        'Management Consulting', 'B2B startup',
#        'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience',
#        'Design', 'B2B Travel', 'Interior Design',
#        'Manchester, Greater Manchester', 'Product studio',
#        'Aviation & Aerospace', 'Staffing & Recruiting'], dtype=object)

# %%
data_2021.loc[data_2021["Sector"] == 'Hauz Khas']
# Out:
#     Company/Brand  Founded       HeadQuarter     Sector  \
# 241    MasterChow   2020.0  Food & Beverages  Hauz Khas
# 255    MasterChow   2020.0  Food & Beverages  Hauz Khas
#
#                             What it does                       Founders  \
# 241  A ready-to-cook Asian cuisine brand  Vidur Kataria, Sidhanth Madan
# 255  A ready-to-cook Asian cuisine brand  Vidur Kataria, Sidhanth Madan
#
#          Investor Amount($) Stage
# 241  WEH Ventures   $461000  Seed
# 255  WEH Ventures   $461000  Seed

# %%
data_2021.loc[data_2021["Company/Brand"] == "MasterChow", ["HeadQuarter", "Sector"]] = ["Hauz Khas", "Food & Beverages"]
data_2021.loc[data_2021["Company/Brand"] == "MasterChow"]
# Out:
#     Company/Brand  Founded HeadQuarter            Sector  \
# 241    MasterChow   2020.0   Hauz Khas  Food & Beverages
# 255    MasterChow   2020.0   Hauz Khas  Food & Beverages
#
#                             What it does                       Founders  \
# 241  A ready-to-cook Asian cuisine brand  Vidur Kataria, Sidhanth Madan
# 255  A ready-to-cook Asian cuisine brand  Vidur Kataria, Sidhanth Madan
#
#          Investor Amount($) Stage
# 241  WEH Ventures   $461000  Seed
# 255  WEH Ventures   $461000  Seed

# %%
data_2021.drop([255], axis = 0, inplace = True)

# %%
data_2021.loc[data_2021["Sector"] == 'Manchester, Greater Manchester']
# Out:
#      Company/Brand  Founded                        HeadQuarter  \
# 1176          Peak   2014.0  Information Technology & Services
#
#                               Sector  \
# 1176  Manchester, Greater Manchester
#
#                                            What it does     Founders  \
# 1176  Peak helps the world's smartest companies put ...  Atul Sharma
#
#                     Investor  Amount($)     Stage
# 1176  SoftBank Vision Fund 2  $75000000  Series C

# %%
#'Manchester, Greater Manchester'
data_2021.loc[data_2021["Company/Brand"] == "Peak", ["HeadQuarter", "Sector"]] = ["Manchester", "Information Technology & Services"]
data_2021.loc[data_2021["Company/Brand"] == "Peak"]
# Out:
#      Company/Brand  Founded HeadQuarter                             Sector  \
# 1176          Peak   2014.0  Manchester  Information Technology & Services
#
#                                            What it does     Founders  \
# 1176  Peak helps the world's smartest companies put ...  Atul Sharma
#
#                     Investor  Amount($)     Stage
# 1176  SoftBank Vision Fund 2  $75000000  Series C

# %%
data_2021.loc[data_2021["Sector"] == 'Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience']
# Out:
#      Company/Brand  Founded          HeadQuarter  \
# 1100      Sochcast   2020.0  Online Media\t#REF!
#
#                                                  Sector  \
# 1100  Sochcast is an Audio experiences company that ...
#
#                                            What it does  \
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana, A...
#
#                                      Founders      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal  $Undisclosed       NaN   NaN

# %%
data_2021.loc[data_2021["Company/Brand"] == "Sochcast", ["HeadQuarter", "Sector",'What it does','Founders','Investor']] = [np.nan, 'Online Media','Sochcast is an Audio experiences company that give the listener and creators an Immersive Audio experience','CA Harvinderjit Singh Bhatia, Garima Surana','Vinners, Raj Nayak, Amritaanshu Agrawal']
data_2021.loc[data_2021["Company/Brand"] == "Sochcast"]
# Out:
#      Company/Brand  Founded HeadQuarter        Sector  \
# 1100      Sochcast   2020.0         NaN  Online Media
#
#                                            What it does  \
# 1100  Sochcast is an Audio experiences company that ...
#
#                                          Founders  \
# 1100  CA Harvinderjit Singh Bhatia, Garima Surana
#
#                                      Investor Amount($) Stage
# 1100  Vinners, Raj Nayak, Amritaanshu Agrawal       NaN   NaN

# %%
data_2021.loc[data_2021["Sector"] == "MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India."]
# Out:
#     Company/Brand  Founded HeadQuarter  \
# 257       MoEVing   2021.0    Gurugram
#
#                                                 Sector  \
# 257  MoEVing is India's only Electric Mobility focu...
#
#                     What it does  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Founders  Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi  $5000000      Seed   NaN

# %%
data_2021.loc[data_2021["Company/Brand"] == "MoEVing", ["Sector",'What it does','Founders','Investor','Amount($)','Stage']] = [np.nan,"MoEVing is India's only Electric Mobility focused Technology Platform with a vision to accelerate EV adoption in India.",'Vikash Mishra, Mragank Jain','Anshuman Maheshwary, Dr Srihari Raju Kalidindi','$5000000','Seed']
data_2021.loc[data_2021["Company/Brand"] == "MoEVing"]
# Out:
#     Company/Brand  Founded HeadQuarter Sector  \
# 257       MoEVing   2021.0    Gurugram    NaN
#
#                                           What it does  \
# 257  MoEVing is India's only Electric Mobility focu...
#
#                         Founders  \
# 257  Vikash Mishra, Mragank Jain
#
#                                            Investor Amount($) Stage
# 257  Anshuman Maheshwary, Dr Srihari Raju Kalidindi  $5000000  Seed

# %%
data_2021.loc[data_2021["Sector"] == 'Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.']
# Out:
#           Company/Brand  Founded             HeadQuarter  \
# 242  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
# 256  Fullife Healthcare   2009.0  Pharmaceuticals\t#REF!
#
#                                                 Sector  What it does  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Founders   Investor Amount($) Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C   NaN

# %%
data_2021.loc[data_2021["Company/Brand"] == "Fullife Healthcare", ['HeadQuarter',"Sector",'What it does','Founders','Investor','Amount($)','Stage']] = [np.nan,'Pharmaceuticals','Primary Business is Development and Manufacturing of Novel Healthcare Products in Effervescent forms using imported propriety ingredients.','Varun Khanna','Morgan Stanley Private Equity Asia','$22000000','Series C']
data_2021.loc[data_2021["Company/Brand"] == "Fullife Healthcare"]
# Out:
#           Company/Brand  Founded HeadQuarter           Sector  \
# 242  Fullife Healthcare   2009.0         NaN  Pharmaceuticals
# 256  Fullife Healthcare   2009.0         NaN  Pharmaceuticals
#
#                                           What it does      Founders  \
# 242  Primary Business is Development and Manufactur...  Varun Khanna
# 256  Primary Business is Development and Manufactur...  Varun Khanna
#
#                                Investor  Amount($)     Stage
# 242  Morgan Stanley Private Equity Asia  $22000000  Series C
# 256  Morgan Stanley Private Equity Asia  $22000000  Series C

# %%
data_2021.drop([242], axis = 0, inplace = True)

# %%
data_2021['Sector'].unique()
# Out:
# array(['AI startup', 'EdTech', 'B2B E-commerce', 'FinTech',
#        'Home services', 'HealthTech', 'Tech Startup', 'E-commerce',
#        'B2B service', 'Helathcare', 'Renewable Energy', 'Electronics',
#        'IT startup', 'Food & Beverages', 'Aeorspace', 'Deep Tech',
#        'Dating', 'Gaming', 'Robotics', 'Retail', 'Food', 'Oil and Energy',
#        'AgriTech', 'Telecommuncation', 'Milk startup', 'AI Chatbot', 'IT',
#        'Logistics', 'Hospitality', 'Fashion', 'Marketing',
#        'Transportation', 'LegalTech', 'Food delivery', 'Automotive',
#        'SaaS startup', 'Fantasy sports', 'Video communication',
#        'Social Media', 'Skill development', 'Rental', 'Recruitment',
#        'HealthCare', 'Sports', 'Computer Games', 'Consumer Goods',
#        'Information Technology', 'Apparel & Fashion',
#        'Logistics & Supply Chain', 'Healthtech', 'Healthcare',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual',
#        'Financial Services', 'Industrial Automation', 'Health',
#        'Lifestyle', 'IoT', 'Banking', 'Computer software', 'Tech startup',
#        'Digital mortgage', 'Information Technology & Services',
#        'Furniture', 'B2B marketplace', 'Healtcare', 'Location Analytics',
#        'Media', 'Consumer Electronics', 'Tobacco', 'Deeptech',
#        'Insuretech', 'MLOps platform', 'Venture Capital', 'Pet care',
#        'Drone', 'Wholesale', 'Construction', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Insurance', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Music', 'Pharmaceuticals', nan,
#        'Cosmetics', 'Mobility', 'Social media', 'Real Estate',
#        'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Social commerce', 'Mobile Games', 'Food Production', 'Podcast',
#        'HeathTech', 'Battery', 'Content publishing', 'Water purification',
#        'Content commerce', 'Innovation Management', 'Software company',
#        'Automation', 'Food Industry', 'Celebrity Engagement',
#        'Trading platform', 'Personal Care', 'Cannabis startup',
#        'Blogging', 'Consulting', 'BioTechnology', 'B2B Marketplace',
#        'Health care', 'Social audio', 'Fashion and lifestyle',
#        'Delivery service', 'B2B Manufacturing', 'Home Decor', 'Solar',
#        'TaaS startup', 'EV startup', 'HR Tech', 'Blockchain startup',
#        'Food and Beverages', 'Beverages', 'Manufacturing startup',
#        'Cryptocurrency', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'Blockchain', 'Fitness', 'D2C', 'Automobile',
#        'Environmental Services', 'Merchandise', 'Facilities Services',
#        'Marketing & Advertising', 'Human Resources', 'Eyewear',
#        'D2C Business', 'Biotechnology', 'Farming', 'NFT Marketplace',
#        'Internet', 'SpaceTech', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'Software', 'Nutrition', 'D2C startup', 'Innovation management',
#        'Community platform', 'Venture capitalist', 'Networking',
#        'Commercial Real Estate', 'AR startup', 'Consumer service',
#        'Consumer goods', 'MarTech', 'Advertisement', 'Content creation',
#        'Augmented reality', 'Rental space', 'Bike Rental',
#        'Beauty products', 'Tourism', 'FemTech', 'Cultural', 'Co-working',
#        'InsureTech', 'Supply chain platform', 'Social platform',
#        'CleanTech', 'Real estate', 'AI company', 'Sports startup',
#        'Matrimony', 'Crypto', 'Clothing', 'Analytics', 'Finance',
#        'IoT platform', 'Commerce', 'Defense & Space', 'Entertainment',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy', 'EV',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Nanotechnology',
#        'Community', 'Higher Education', 'B2B',
#        'Mechanical Or Industrial Engineering', 'D2C jewellery',
#        'Sales and Distribution', 'SaaS', 'Information Services',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Veterinary',
#        'Arts & Crafts', 'Investment Management', 'Education',
#        'Management Consulting', 'B2B startup', 'Design', 'B2B Travel',
#        'Interior Design', 'Product studio', 'Aviation & Aerospace',
#        'Staffing & Recruiting'], dtype=object)

# %%
#amount
data_2021['Amount($)'].unique()
# Out:
# array(['$1,200,000', '$120,000,000', '$30,000,000', '$51,000,000',
#        '$2,000,000', '$188,000,000', '$200,000', 'Undisclosed',
#        '$1,000,000', '$3,000,000', '$100,000', '$700,000', '$9,000,000',
#        '$40,000,000', '$49,000,000', '$400,000', '$300,000',
#        '$25,000,000', '$160,000,000', '$150,000', '$1,800,000',
#        '$5,000,000', '$850,000', '$53,000,000', '$500,000', '$1,100,000',
#        '$6,000,000', '$800,000', '$10,000,000', '$21,000,000',
#        '$7,500,000', '$26,000,000', '$7,400,000', '$1,500,000',
#        '$600,000', '$800,000,000', '$17,000,000', '$3,500,000',
#        '$15,000,000', '$215,000,000', '$2,500,000', '$350,000,000',
#        '$5,500,000', '$83,000,000', '$110,000,000', '$500,000,000',
#        '$65,000,000', '$150,000,000,000', '$300,000,000', '$2,200,000',
#        '$35,000,000', '$140,000,000', '$4,000,000', '$13,000,000', nan,
#        '$Undisclosed', '$2000000', '$800000', '$6000000', '$2500000',
#        '$9500000', '$13000000', '$5000000', '$8000000', '$1000000',
#        'Upsparks', '$200000', '$12000000', '$1500000', '$1700000',
#        '$5500000', '$400000', '$150000000', '$4000000', '$100000000',
#        '$500000', '$15000000', '$10000000', '$40000000', '$225000000',
#        '$6700000', '$1300000', '$20000000', '$250000', '$21000000',
#        '$1200000', '$52000000', '$3800000', '$17500000', '$42000000',
#        '$2300000', '$7000000', '$30000000', '$450000000', '$28000000',
#        '$300000', '$3500000', '$8500000', '$25000000', '$3000000',
#        '$37000000', '$370000000', '$700000', '$16000000', '$100000',
#        '$44000000', '$770000', '$125000000', '$35000000', '$50000000',
#        '$4900000', '$145000000', '$22000000', '$70000000', '$6600000',
#        '$32000000', '$24000000', '$725000', '$461000', '$96000000',
#        '$60000000', '$500000000', '$266000000', '$4500000', '$325000000',
#        '$6500000', '$1600000', '$225000', '$85000000', '$235000',
#        '$260000', '$2900000', '$53000000', '$1100000', '$150000',
#        '$86000000', '$130000', '$$100,00', '$111000000', '$265000',
#        '$76000000', '$100,000,000', '$75,000,000', '$3,800,000',
#        '$12,000,000', '$1,600,000', '$260,000', '$1,000,000,000',
#        '$18,000,000', '$20,000,000', '$350,000', '$95,000,000',
#        '$4,100,000', '$5,200,000', '$8,000,000', '$1,400,000',
#        '$2,600,000', '$900,000', '$250,000', '$16,000,000', '$7,000,000',
#        '$11,000,000', '$50,000,000', '$14,300,000', '$81,000,000',
#        '$1,300,000', '$8,200,000', '$280,000,000', '$70,000,000',
#        '$720,000', '$600000', '$9000000', '$1800000', '$330000',
#        '$undisclosed', '$200000000', '$36000000', '$67000000',
#        '$10200000', '$220000000', '$108000000', '$75000000', '$450000',
#        '$660000000', 'ah! Ventures', '$45000000', '$3200000', '$370000',
#        'Pre-series A', 'ITO Angel Network, LetsVenture', '$48000000',
#        '$3600000', '$11000000', '$192000000', '$65000000', '$1400000',
#        '$1900000', '$41000000', '$144000000', '$5200000', '$270000000',
#        '$140000', '$250000000', '$320000', '$350000000', '$4800000',
#        '$38000000', '$125000', '$26000000', '$64000000', '$620000',
#        '$900000', 'JITO Angel Network, LetsVenture', '$2600000',
#        '$1,250,000', '$400,000,000', '$1,700,000', '$27,000,000',
#        '$234,000,000', '$460,000,000', '$13,500,000', '$5,100,000',
#        '$195,000,000', '$125,000', '$45,000,000', '$200,000,000',
#        '$7,300,000', '$6,300,000', '$12,500,000', '$24,000,000',
#        '$140,000', '$16,500,000', '$340,000', '$43,000,000',
#        '$150,000,000', '$3300000', '$92000000', '$17000000', '$135000000',
#        '$$1,55,000', '$2100000', '$840000000', '$248000000', '$4300000',
#        '$570000', '$2200000', '$4700000', '$300000000', '$260000000',
#        '$140000000', '$175000000', '$19000000', '$810000', '$7500000',
#        '$600000000', '$90000000', '$5700000', '$6750000', '$78000000',
#        '$5400000', '$115000000', '$255000000', '$18000000', '$570000000',
#        '$550000', '$2700000', '$4200000', '$31000000', '$540000',
#        '$14000000', '$340000', '$', '$6200000', 'Seed', '$750000',
#        '$6300000', '$23000000', '$55000000'], dtype=object)

# %%
data_2021.loc[data_2021["Amount($)"] == "ah! Ventures"]
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 538   Little Leap   2020.0   New Delhi  EdTech
#
#                             What it does  \
# 538  Soft Skills that make Smart Leaders
#
#                                               Founders      Investor  \
# 538  Holistic Development Programs for children in ...  Vishal Gupta
#
#         Amount($)    Stage
# 538  ah! Ventures  $300000

# %%
data_2021.loc[data_2021["Company/Brand"] == "Little Leap", ["Amount($)", "Stage", "Investor"]] = ["$300000", np.nan, "ah! Ventures"]
data_2021.loc[data_2021["Investor"] == "ah! Ventures"]
# Out:
#      Company/Brand  Founded HeadQuarter                             Sector  \
# 356            OwO   2020.0    Gurugram                         E-commerce
# 538    Little Leap   2020.0   New Delhi                             EdTech
# 840      Klassroom   2016.0      Mumbai                             EdTech
# 1133      Enercomp   2013.0   Ahmedabad  Information Technology & Services
#
#                                            What it does  \
# 356   Shop packaged drinking water, beverages from y...
# 538                 Soft Skills that make Smart Leaders
# 840   Klassroom offers a one-of-a-kind LIVE interact...
# 1133  Enercomp Solutions Pvt Ltd provide drone based...
#
#                                                Founders      Investor  \
# 356                                         Hardev Sahu  ah! Ventures
# 538   Holistic Development Programs for children in ...  ah! Ventures
# 840                                         Alka Javeri  ah! Ventures
# 1133                                 SURESH SHAHDADPURI  ah! Ventures
#
#      Amount($)         Stage
# 356   $200,000           NaN
# 538    $300000           NaN
# 840   $200,000  Pre-series A
# 1133   $200000           NaN

# %%
data_2021.loc[data_2021["Amount($)"] == "Pre-series A"]
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 545     AdmitKard   2016.0       Noida  EdTech
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders  Investor     Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!  $1000000  Pre-series A
#
#     Stage
# 545   NaN

# %%
data_2021.loc[data_2021["Company/Brand"] == "AdmitKard", ["Amount($)", "Stage", "Investor"]] = ["$1000000", "Pre-series A",np.nan]
data_2021.loc[data_2021["Company/Brand"] == "AdmitKard"]
# Out:
#     Company/Brand  Founded HeadQuarter  Sector  \
# 545     AdmitKard   2016.0       Noida  EdTech
#
#                                           What it does  \
# 545  A tech solution for end to end career advisory...
#
#                                              Founders Investor Amount($)  \
# 545  Vamsi Krishna, Pulkit Jain, Gaurav Munjal\t#REF!      NaN  $1000000
#
#             Stage
# 545  Pre-series A

# %%
data_2021.loc[data_2021["Amount($)"] == 'Series C']
# Out:
# Empty DataFrame
# Columns: [Company/Brand, Founded, HeadQuarter, Sector, What it does, Founders, Investor, Amount($), Stage]
# Index: []

# %%
data_2021.loc[data_2021["Amount($)"] == "Seed"]
# Out:
#      Company/Brand  Founded HeadQuarter                    Sector  \
# 1148     Godamwale   2016.0      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                        Founders        Investor Amount($)  \
# 1148  Basant Kumar, Vivek Tiwari, Ranbir Nandan  1000000\t#REF!      Seed
#
#      Stage
# 1148   NaN

# %%
data_2021.loc[data_2021["Company/Brand"] == "Godamwale", ["Amount($)", "Stage", "Investor"]] = ["$1000000", "Seed",np.nan]
data_2021.loc[data_2021["Company/Brand"] == "Godamwale"]
# Out:
#      Company/Brand  Founded HeadQuarter                    Sector  \
# 1148     Godamwale   2016.0      Mumbai  Logistics & Supply Chain
#
#                                            What it does  \
# 1148  Godamwale is tech enabled integrated logistics...
#
#                                        Founders Investor Amount($) Stage
# 1148  Basant Kumar, Vivek Tiwari, Ranbir Nandan      NaN  $1000000  Seed

# %%
data_2021.loc[data_2021["Amount($)"] == 'ITO Angel Network, LetsVenture']
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 551         BHyve   2020.0      Mumbai  Human Resources
#
#                                           What it does           Founders  \
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC
#
#                             Investor                       Amount($)    Stage
# 551  Omkar Pandharkame, Ketaki Ogale  ITO Angel Network, LetsVenture  $300000

# %%
data_2021.loc[data_2021["Company/Brand"] == "BHyve", ["Amount($)", "Stage"]] = ["$300000",np.nan]
data_2021.loc[data_2021["Company/Brand"] == "BHyve"]
# Out:
#     Company/Brand  Founded HeadQuarter           Sector  \
# 551         BHyve   2020.0      Mumbai  Human Resources
#
#                                           What it does           Founders  \
# 551  A Future of Work Platform for diffusing Employ...  Backed by 100x.VC
#
#                             Investor Amount($) Stage
# 551  Omkar Pandharkame, Ketaki Ogale   $300000   NaN

# %%
data_2021.loc[data_2021["Amount($)"] == 'JITO Angel Network, LetsVenture']
# Out:
#         Company/Brand  Founded HeadQuarter  Sector  \
# 677  Saarthi Pedagogy   2015.0   Ahmadabad  EdTech
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor                        Amount($)     Stage
# 677  Sushil Agarwal  JITO Angel Network, LetsVenture  $1000000

# %%
data_2021.loc[data_2021["Company/Brand"] == "Saarthi Pedagogy", ["Amount($)", "Stage"]] = ["$1000000",np.nan]
data_2021.loc[data_2021["Company/Brand"] == "Saarthi Pedagogy"]
# Out:
#         Company/Brand  Founded HeadQuarter  Sector  \
# 677  Saarthi Pedagogy   2015.0   Ahmadabad  EdTech
#
#                                           What it does  Founders  \
# 677  India's fastest growing Pedagogy company, serv...  Pedagogy
#
#            Investor Amount($) Stage
# 677  Sushil Agarwal  $1000000   NaN

# %%
data_2021.loc[data_2021["Amount($)"] == 'Upsparks']
# Out:
#     Company/Brand  Founded     HeadQuarter          Sector  \
# 98        FanPlay   2020.0  Computer Games  Computer Games
# 111       FanPlay   2020.0  Computer Games  Computer Games
#
#                                           What it does Founders  \
# 98   A real money game app specializing in trivia g...   YC W21
# 111  A real money game app specializing in trivia g...   YC W21
#
#                         Investor Amount($)     Stage
# 98   Pritesh Kumar, Bharat Gupta  Upsparks  $1200000
# 111  Pritesh Kumar, Bharat Gupta  Upsparks  $1200000

# %%
data_2021.loc[data_2021["Company/Brand"] == "FanPlay", ['HeadQuarter',"Amount($)", "Stage", "Investor"]] = [np.nan,"$1200000", np.nan, "Upsparks"]
data_2021.drop([98], axis = 0, inplace = True)
data_2021.loc[data_2021["Company/Brand"] == "FanPlay"]
# Out:
#     Company/Brand  Founded HeadQuarter          Sector  \
# 111       FanPlay   2020.0         NaN  Computer Games
#
#                                           What it does Founders  Investor  \
# 111  A real money game app specializing in trivia g...   YC W21  Upsparks
#
#     Amount($) Stage
# 111  $1200000   NaN

# %%
#clean Amount column and relapce NaN in founded in the data frame
data_2021["Amount($)"] = data_2021["Amount($)"].apply(str)
data_2021["Amount($)"].replace("", 0, inplace = True, regex=True)
data_2021["Amount($)"].replace(",", "", inplace = True, regex=True)
data_2021["Amount($)"].replace("Undisclosed", np.nan, inplace = True, regex=True)
data_2021["Amount($)"].replace("undisclosed", np.nan, inplace = True, regex=True)
data_2021["Amount($)"].replace("Undiclsosed", np.nan, inplace = True, regex=True)
data_2021["Amount($)"].replace("Undislosed", np.nan, inplace = True, regex=True)
data_2021["Amount($)"] = data_2021["Amount($)"].apply(lambda x: (str(x).replace("$","")))
data_2021["Founded"].replace("nan", np.nan, inplace = True, regex=True)

# %%
data_2021["Amount($)"].astype("float")
# Out:
# 0         1200000.0
# 1       120000000.0
# 2        30000000.0
# 3        51000000.0
# 4         2000000.0
#            ...
# 1204      3000000.0
# 1205     20000000.0
# 1206     55000000.0
# 1207     26000000.0
# 1208      8000000.0
# Name: Amount($), Length: 1206, dtype: float64

# %%
data_2021['Amount($)'].unique()
# Out:
# array(['1200000', '120000000', '30000000', '51000000', '2000000',
#        '188000000', '200000', 'nan', '1000000', '3000000', '100000',
#        '700000', '9000000', '40000000', '49000000', '400000', '300000',
#        '25000000', '160000000', '150000', '1800000', '5000000', '850000',
#        '53000000', '500000', '1100000', '6000000', '800000', '10000000',
#        '21000000', '7500000', '26000000', '7400000', '1500000', '600000',
#        '800000000', '17000000', '3500000', '15000000', '215000000',
#        '2500000', '350000000', '5500000', '83000000', '110000000',
#        '500000000', '65000000', '150000000000', '300000000', '2200000',
#        '35000000', '140000000', '4000000', '13000000', '9500000',
#        '8000000', '12000000', '1700000', '150000000', '100000000',
#        '225000000', '6700000', '1300000', '20000000', '250000',
#        '52000000', '3800000', '17500000', '42000000', '2300000',
#        '7000000', '450000000', '28000000', '8500000', '37000000',
#        '370000000', '16000000', '44000000', '770000', '125000000',
#        '50000000', '4900000', '145000000', '22000000', '70000000',
#        '6600000', '32000000', '24000000', '725000', '461000', '96000000',
#        '60000000', '266000000', '4500000', '325000000', '6500000',
#        '1600000', '225000', '85000000', '235000', '260000', '2900000',
#        '86000000', '130000', '10000', '111000000', '265000', '76000000',
#        '75000000', '1000000000', '18000000', '350000', '95000000',
#        '4100000', '5200000', '1400000', '2600000', '900000', '11000000',
#        '14300000', '81000000', '8200000', '280000000', '720000', '330000',
#        '200000000', '36000000', '67000000', '10200000', '220000000',
#        '108000000', '450000', '660000000', '45000000', '3200000',
#        '370000', '48000000', '3600000', '192000000', '1900000',
#        '41000000', '144000000', '270000000', '140000', '250000000',
#        '320000', '4800000', '38000000', '125000', '64000000', '620000',
#        '1250000', '400000000', '27000000', '234000000', '460000000',
#        '13500000', '5100000', '195000000', '7300000', '6300000',
#        '12500000', '16500000', '340000', '43000000', '3300000',
#        '92000000', '135000000', '155000', '2100000', '840000000',
#        '248000000', '4300000', '570000', '4700000', '260000000',
#        '175000000', '19000000', '810000', '600000000', '90000000',
#        '5700000', '6750000', '78000000', '5400000', '115000000',
#        '255000000', '570000000', '550000', '2700000', '4200000',
#        '31000000', '540000', '14000000', '0', '6200000', '750000',
#        '23000000', '55000000'], dtype=object)

# %%
data_2021['What it does'].unique()
# Out:
# array(['Unbox Robotics builds on-demand AI-driven warehouse robotics solutions, which can be deployed using limited foot-print, time, and capital.',
#        'UpGrad is an online higher education platform.',
#        'LEAD School offers technology based school transformation system that assures excellent learning for every child.',
#        ..., 'International education loans for high potential students.',
#        'Collegedekho.com is Student’s Partner, Friend & Confidante, To Help Him Take a Decision and Move On to His Career Goals.',
#        'India’s first socially distributed full stack financial services platform for small town India'],
#       dtype=object)

# %%
data_2021['Stage'].unique()
# Out:
# array(['Pre-series A', nan, 'Series D', 'Series C', 'Seed', 'Series B',
#        'Series E', 'Pre-seed', 'Series A', 'Pre-series B', 'Debt',
#        'Bridge', 'Seed+', 'Series F2', 'Series A+', 'Series G',
#        'Series F', 'Series H', 'Series B3', 'PE', 'Series F1',
#        'Pre-series A1', 'Early seed', 'Series D1', '$6000000', 'Seies A',
#        'Pre-series', 'Series A2', 'Series I'], dtype=object)

# %%
data_2021[data_2021['Stage']=='$6000000']
# Out:
#     Company/Brand  Founded HeadQuarter                  Sector  \
# 674  MYRE Capital   2020.0      Mumbai  Commercial Real Estate
#
#                             What it does  \
# 674  Democratising Real Estate Ownership
#
#                                     Founders     Investor Amount($)     Stage
# 674  Own rent yielding commercial properties  Aryaman Vir       nan  $6000000

# %%
data_2021.loc[data_2021["Company/Brand"] == "MYRE Capital", ["Amount($)", "Stage"]] = ["6000000",np.nan]
data_2021.loc[data_2021["Company/Brand"] == "MYRE Capital"]
# Out:
#     Company/Brand  Founded HeadQuarter                  Sector  \
# 674  MYRE Capital   2020.0      Mumbai  Commercial Real Estate
#
#                             What it does  \
# 674  Democratising Real Estate Ownership
#
#                                     Founders     Investor Amount($) Stage  \
# 674  Own rent yielding commercial properties  Aryaman Vir   6000000   NaN
#
#      Funding Year
# 674          2021

# %%
data_2021['Founders'].unique()
# Out:
# array(['Pramod Ghadge, Shahid Memon',
#        'Mayank Kumar, Phalgun Kompalli, Ravijot Chugh, Ronnie Screwvala',
#        'Smita Deorah, Sumeet Mehta', ..., 'Bala Sarda',
#        'Arnav Kumar, Vaibhav Singh', 'Vishal Chopra, Himanshu Gupta'],
#       dtype=object)

# %%
data_2021.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1206 entries, 0 to 1208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  1206 non-null   object
#  1   Founded        1205 non-null   float64
#  2   HeadQuarter    1202 non-null   object
#  3   Sector         1205 non-null   object
#  4   What it does   1206 non-null   object
#  5   Founders       1202 non-null   object
#  6   Investor       1142 non-null   object
#  7   Amount($)      1206 non-null   object
#  8   Stage          778 non-null    object
# dtypes: float64(1), object(8)
# memory usage: 94.2+ KB

# %%
data_2021['Funding Year']=2021
data_2021
# Out:
#        Company/Brand  Founded HeadQuarter                 Sector  \
# 0     Unbox Robotics   2019.0   Bangalore             AI startup
# 1             upGrad   2015.0      Mumbai                 EdTech
# 2        Lead School   2012.0      Mumbai                 EdTech
# 3            Bizongo   2015.0      Mumbai         B2B E-commerce
# 4           FypMoney   2021.0    Gurugram                FinTech
# ...              ...      ...         ...                    ...
# 1204        Gigforce   2019.0    Gurugram  Staffing & Recruiting
# 1205          Vahdam   2015.0   New Delhi       Food & Beverages
# 1206    Leap Finance   2019.0   Bangalore     Financial Services
# 1207    CollegeDekho   2015.0    Gurugram                 EdTech
# 1208          WeRize   2019.0   Bangalore     Financial Services
#
#                                            What it does  \
# 0     Unbox Robotics builds on-demand AI-driven ware...
# 1        UpGrad is an online higher education platform.
# 2     LEAD School offers technology based school tra...
# 3     Bizongo is a business-to-business online marke...
# 4     FypMoney is Digital NEO Bank for Teenagers, em...
# ...                                                 ...
# 1204                  A gig/on-demand staffing company.
# 1205  VAHDAM is among the world’s first vertically i...
# 1206  International education loans for high potenti...
# 1207  Collegedekho.com is Student’s Partner, Friend ...
# 1208  India’s first socially distributed full stack ...
#
#                                                Founders  \
# 0                           Pramod Ghadge, Shahid Memon
# 1     Mayank Kumar, Phalgun Kompalli, Ravijot Chugh,...
# 2                            Smita Deorah, Sumeet Mehta
# 3               Aniket Deb, Ankit Tomar, Sachin Agrawal
# 4                                         Kapil Banwari
# ...                                                 ...
# 1204                        Chirag Mittal, Anirudh Syal
# 1205                                         Bala Sarda
# 1206                         Arnav Kumar, Vaibhav Singh
# 1207                                       Ruchir Arora
# 1208                      Vishal Chopra, Himanshu Gupta
#
#                                            Investor  Amount($)         Stage  \
# 0                       BEENEXT, Entrepreneur First    1200000  Pre-series A
# 1          Unilazer Ventures, IIFL Asset Management  120000000           NaN
# 2                  GSV Ventures, Westbridge Capital   30000000      Series D
# 3                            CDC Group, IDG Capital   51000000      Series C
# 4     Liberatha Kallat, Mukesh Yadav, Dinesh Nagpal    2000000          Seed
# ...                                             ...        ...           ...
# 1204                                Endiya Partners    3000000  Pre-series A
# 1205                                       IIFL AMC   20000000      Series D
# 1206                                   Owl Ventures   55000000      Series C
# 1207               Winter Capital, ETS, Man Capital   26000000      Series B
# 1208                 3one4 Capital, Kalaari Capital    8000000      Series A
#
#       Funding Year
# 0             2021
# 1             2021
# 2             2021
# 3             2021
# 4             2021
# ...            ...
# 1204          2021
# 1205          2021
# 1206          2021
# 1207          2021
# 1208          2021
#
# [1206 rows x 10 columns]

# %% [markdown]
# ## Dataset overview
#
# Have a look at the loaded datsets using the following methods: `.head(), .info()`

# %%
#combining data into one 
sets=[data_2018,data_2019,data_2020, data_2021]
startup_data = pd.concat(sets)

# %%
startup_data.head()
# Out:
#      Company/Brand                Sector     Stage  Amount($) HeadQuarter  \
# 0  TheCollegeFever       Brand Marketing      Seed   250000.0   Bangalore
# 1  Happy Cow Dairy           Agriculture      Seed   584000.0      Mumbai
# 2       MyLoanCare                Credit  Series A   949000.0     Gurgaon
# 3      PayMe India    Financial Services     Angel  2000000.0       Noida
# 4         Eunimart  E-Commerce Platforms      Seed        NaN   Hyderabad
#
#                                         What it does  Funding Year Founded  \
# 0  TheCollegeFever is a hub for fun, fiesta and f...          2018     NaN
# 1  A startup which aggregates milk from dairy far...          2018     NaN
# 2          Leading Online Loans Marketplace in India          2018     NaN
# 3  PayMe India is an innovative FinTech organizat...          2018     NaN
# 4  Eunimart is a one stop solution for merchants ...          2018     NaN
#
#   Founders Investor
# 0      NaN      NaN
# 1      NaN      NaN
# 2      NaN      NaN
# 3      NaN      NaN
# 4      NaN      NaN

# %%
startup_data["Amount($)"].astype("float")
# Out:
# 0         250000.0
# 1         584000.0
# 2         949000.0
# 3        2000000.0
# 4              NaN
#            ...
# 1204     3000000.0
# 1205    20000000.0
# 1206    55000000.0
# 1207    26000000.0
# 1208     8000000.0
# Name: Amount($), Length: 2876, dtype: float64

# %%
startup_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2876 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2876 non-null   object
#  1   Sector         2827 non-null   object
#  2   Stage          1898 non-null   object
#  3   Amount($)      2716 non-null   object
#  4   HeadQuarter    2853 non-null   object
#  5   What it does   2876 non-null   object
#  6   Funding Year   2876 non-null   int64
#  7   Founded        2107 non-null   object
#  8   Founders       2331 non-null   object
#  9   Investor       2248 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 247.2+ KB

# %%
startup_data.describe()
# Out:
#        Funding Year
# count   2876.000000
# mean    2020.022601
# std        1.087083
# min     2018.000000
# 25%     2020.000000
# 50%     2020.000000
# 75%     2021.000000
# max     2021.000000

# %% [markdown]
# # Feature processing
# Here is the section to **clean** and **process** the features of the dataset.

# %%
startup_data.isnull().sum()
# Out:
# Company/Brand      0
# Sector            49
# Stage            978
# Amount($)        160
# HeadQuarter       23
# What it does       0
# Funding Year       0
# Founded          769
# Founders         545
# Investor         628
# dtype: int64

# %%
startup_data['Founded'].unique()
# Out:
# array([nan, 2014.0, 2004.0, 2013.0, 2010.0, 2018.0, 2019.0, 2017.0,
#        2011.0, 2015.0, 2016.0, 2012.0, 2008.0, '2019', '2018', '2020',
#        '2016', '2008', '2015', '2017', '2014', '1998', '2007', '2011',
#        '1982', '2013', '2009', '2012', '1995', '2010', '2006', '1978',
#        '1999', '1994', '2005', '1973', '2002', '2004', '2001', 2021.0,
#        2020.0, 1993.0, 1999.0, 1989.0, 2009.0, 2002.0, 1994.0, 2006.0,
#        2000.0, 2007.0, 1978.0, 2003.0, 1998.0, 1991.0, 1984.0, 2005.0,
#        1963.0], dtype=object)

# %%
startup_data['Founded']=startup_data['Founded'].replace(np.nan,0)

# %%
startup_data['Founded']=startup_data['Founded'].astype(int)

# %%
startup_data['Founded']=startup_data['Founded'].replace(0,'N/A')

# %%
#updating the columns 
startup_data.update(startup_data[['HeadQuarter','Sector','What it does', 'Founders', 'Investor','Stage']].fillna('N/A'))

# %%
startup_data[startup_data['Amount($)'].isnull()]
# Out:
#                  Company/Brand                Sector     Stage Amount($)  \
# 4                     Eunimart  E-Commerce Platforms      Seed       NaN
# 8                 Freightwalla  Information Services      Seed       NaN
# 9           Microchip Payments       Mobile Payments      Seed       NaN
# 10  BizCrum Infotech Pvt. Ltd.                   B2B      Seed       NaN
# 11                     Emojifi              Internet      Seed       NaN
# ..                         ...                   ...       ...       ...
# 45                      Afinoz               Fintech       N/A       NaN
# 54                   Ninjacart      B2B Supply Chain       N/A       NaN
# 55                 Binca Games                 Games       N/A       NaN
# 65                Cubical Labs                   IoT  Series B       NaN
# 75                    Sportido                Sports  Series B       NaN
#
#    HeadQuarter                                       What it does  \
# 4    Hyderabad  Eunimart is a one stop solution for merchants ...
# 8       Mumbai  Freightwalla is an international forwarder tha...
# 9    Bangalore  Microchip payments is a mobile-based payment a...
# 10       Delhi           Building Transactionary B2B Marketplaces
# 11   Bengaluru  Emojifi is an app that provides live emoji, st...
# ..         ...                                                ...
# 45       Noida  Online financial marketplace for customized ra...
# 54         N/A  It connects producers of food directly to reta...
# 55      Mumbai  It offers games that are available across Indi...
# 65         N/A                  Home automation solution provider
# 75       Noida  It is a sports discovery app that helps to fin...
#
#     Funding Year Founded                                          Founders  \
# 4           2018     N/A                                               N/A
# 8           2018     N/A                                               N/A
# 9           2018     N/A                                               N/A
# 10          2018     N/A                                               N/A
# 11          2018     N/A                                               N/A
# ..           ...     ...                                               ...
# 45          2019     N/A                                     Rachna Suneja
# 54          2019    2015  Thirukumaran Nagarajanin, Vasudevan Chinnathambi
# 55          2019    2014                     Rubianca Wadhwa, Sahil Wadhwa
# 65          2019    2013                           Dhruv Ratra, Swati Vyas
# 75          2019    2015              Neeraj Aggarwala, Akhil Ramachandran
#
#                                              Investor
# 4                                                 N/A
# 8                                                 N/A
# 9                                                 N/A
# 10                                                N/A
# 11                                                N/A
# ..                                                ...
# 45                             Fintech innovation lab
# 54                                  Walmart, Flipkart
# 55                                     Sunil Gavaskar
# 65                                   Rockstud Capital
# 75  Inflection Point Ventures, SucSEED Venture Par...
#
# [160 rows x 10 columns]

# %%
#startup_data['Amount($)']=startup_data['Amount($)'].replace('$6000000',6000000)

# %%
startup_data['Amount($)']=startup_data['Amount($)'].astype(float)

# %%
startup_data['Funding Year']=startup_data['Funding Year'].astype(str)

# %%
startup_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2876 entries, 0 to 1208
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company/Brand  2876 non-null   object
#  1   Sector         2876 non-null   object
#  2   Stage          2876 non-null   object
#  3   Amount($)      2328 non-null   float64
#  4   HeadQuarter    2876 non-null   object
#  5   What it does   2876 non-null   object
#  6   Funding Year   2876 non-null   object
#  7   Founded        2876 non-null   object
#  8   Founders       2876 non-null   object
#  9   Investor       2876 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 247.2+ KB

# %%
startup_data['HeadQuarter'].unique()
# Out:
# array(['Bangalore', 'Mumbai', 'Gurgaon', 'Noida', 'Hyderabad',
#        'Bengaluru', 'Kalkaji', 'Delhi', 'India', 'Hubli', 'New Delhi',
#        'Chennai', 'Mohali', 'Kolkata', 'Pune', 'Jodhpur', 'Kanpur',
#        'Ahmedabad', 'Azadpur', 'Haryana', 'Cochin', 'Faridabad', 'Jaipur',
#        'Kota', 'Anand', 'Bangalore City', 'Belgaum', 'Thane', 'Margão',
#        'Indore', 'Alwar', 'Kannur', 'Trivandrum', 'Ernakulam',
#        'Kormangala', 'Uttar Pradesh', 'Andheri', 'Mylapore', 'Ghaziabad',
#        'Kochi', 'Powai', 'Guntur', 'Kalpakkam', 'Bhopal', 'Coimbatore',
#        'Worli', 'Alleppey', 'Chandigarh', 'Guindy', 'Lucknow', 'N/A',
#        'Telangana', 'Gurugram', 'Surat', 'Uttar pradesh', 'Rajasthan',
#        'Tirunelveli', 'nan', 'Singapore', 'Gujarat', 'Kerala', 'Frisco',
#        'California', 'Dhingsara', 'New York', 'Patna', 'San Francisco',
#        'San Ramon', 'Paris', 'Plano', 'Sydney', 'San Francisco Bay Area',
#        'Bangaldesh', 'London', 'Milano', 'Palmwoods', 'France',
#        'Samastipur', 'Irvine', 'Tumkur', 'Newcastle Upon Tyne',
#        'Shanghai', 'Jiaxing', 'Rajastan', 'Ludhiana', 'Dehradun',
#        'San Franciscao', 'Tangerang', 'Berlin', 'Seattle', 'Riyadh',
#        'Seoul', 'Bangkok', 'Warangal', 'Hyderebad', 'Odisha', 'Bihar',
#        'Goa', 'Tamil Nadu', 'Banglore', 'Ahmadabad',
#        'Small Towns, Andhra Pradesh', 'Rajsamand', 'Ranchi',
#        'Faridabad, Haryana', 'Vadodara', 'Hauz Khas', 'Nagpur',
#        'West Bengal', 'Samsitpur', 'Silvassa', 'Thiruvananthapuram',
#        'Roorkee', 'Ambernath', 'Panchkula', 'Mangalore', 'Telugana',
#        'Bhubaneswar', 'Kottayam', 'Beijing', 'Panaji', 'Satara',
#        'Orissia', 'Santra', 'Mountain View, CA', 'Jharkhand', 'Bhilwara',
#        'Guwahati', 'Manchester', 'The Nilgiris', 'Gandhinagar'],
#       dtype=object)

# %%
startup_data[startup_data['HeadQuarter']=='nan']
# Out:
#        Company/Brand                     Sector         Stage    Amount($)  \
# 87           Habitat                     EdTech          Seed     600000.0
# 92            Raskik           Fusion beverages  Pre-series A    1000000.0
# 95     Pravasirojgar                 Job portal           N/A   33000000.0
# 121   Kaagaz Scanner               Scanning app           N/A     575000.0
# 487            Exprs  Nano Distribution Network           N/A    5660000.0
# ...              ...                        ...           ...          ...
# 1035            Byju                     Edtech           N/A  200000000.0
# 1041         Shiksha                     Edtech           N/A     181000.0
# 1045      XpressBees                  Logistics           N/A   10000000.0
# 1047   Wealth Bucket                    Fintech           N/A    3000000.0
# 1051           EpiFi                    Fintech    Seed Round   13200000.0
#
#      HeadQuarter                                       What it does  \
# 87           nan  Habitat, a social learning edtech platform for...
# 92           nan  All new fusion-flavour fruit juices with the g...
# 95           nan             Initiative for blue-collar job workers
# 121          nan  Kaagaz Scanner is the Indian replacement to ba...
# 487          nan  Nano Distribution Centres, enabling seamless c...
# ...          ...                                                ...
# 1035         nan                   Provides online learning classes
# 1041         nan  It makes college selection easy for students l...
# 1045         nan         Provides end to end supply chain solutions
# 1047         nan     An online platform for mutual fund investments
# 1051         nan  It offers customers with a single interface fo...
#
#      Funding Year Founded                                           Founders  \
# 87           2020    2016                        Rohit Pande, Shikhar Sachan
# 92           2020    2019        Vikas Chawla, Abhay Parnerkar, Satyajit Ram
# 95           2020    2020                                          Sonu Sood
# 121          2020    2020               Snehanshu Gandhi, Gaurav Shrishrimal
# 487          2020    2018  Srinivas Madhavam, Srikanth Rajashekhar, Rahul...
# ...           ...     ...                                                ...
# 1035         2020    2011                                    Byju Raveendran
# 1041         2020    2008                                     Kanav Sachdeva
# 1045         2020    2015                     Supam Maheshwari, Amitava Saha
# 1047         2020    2018                         Himanshu Jain, Pulkit Jain
# 1051         2020     N/A                    Sujith Narayanan, Sumit Gwalani
#
#                                  Investor
# 87    Unitus Ventures, Whiteboard Capital
# 92           Venture Catalysts, 9Unicorns
# 95                            GoodWorker.
# 121                      Pravega Ventures
# 487             Sweta Rau, Sandeep Kapoor
# ...                                   ...
# 1035                         Tiger Global
# 1041                Mumbai Angels Network
# 1045                              Alibaba
# 1047            NorthStar, Vinod Khatumal
# 1051        Sequoia India, Ribbit Capital
#
# [94 rows x 10 columns]

# %%
startup_data['HeadQuarter']=startup_data['HeadQuarter'].replace('nan','N/A')

# %%
startup_data['Sector'].unique()
# Out:
# array(['Brand Marketing', 'Agriculture', 'Credit', 'Financial Services',
#        'E-Commerce Platforms', 'Cloud Infrastructure', 'Internet',
#        'Market Research', 'Information Services', 'Mobile Payments',
#        'B2B', 'Apps', 'Food Delivery', 'Industrial Automation',
#        'Automotive', 'Finance', 'Accounting', 'Artificial Intelligence',
#        'Internet of Things', 'Air Transportation', 'Food and Beverage',
#        'Autonomous Vehicles', 'Enterprise Software', 'Logistics',
#        'Insurance', 'Information Technology', 'Blockchain', 'Education',
#        'E-Commerce', 'Renewable Energy', 'E-Learning', 'Clean Energy',
#        'Transportation', 'Fitness', 'Hospitality',
#        'Media and Entertainment', 'Broadcasting', 'EdTech', 'Health Care',
#        'N/A', 'Sports', 'Big Data', 'Cloud Computing', 'Food Processing',
#        'Trading Platform', 'Consumer Goods', 'Wellness', 'Fashion',
#        'Consulting', 'Biotechnology', 'Communities', 'Consumer',
#        'Consumer Applications', 'Mobile', 'Advertising', 'Marketplace',
#        'Aerospace', 'Home Decor', 'Energy', 'Digital Marketing',
#        'Creative Agency', 'Consumer Lending', 'Health Diagnostics',
#        'Banking', 'Embedded Systems', 'Beauty', 'AgTech', 'Credit Cards',
#        'Software', 'Manufacturing', 'Hospital', 'Events', '3D Printing',
#        'Digital Entertainment', 'Funding Platform', 'Classifieds',
#        'Enterprise Resource Planning (ERP)', 'Audio', 'Government',
#        'Digital Media', 'Business Intelligence', 'Children', 'Rental',
#        'Travel', 'Wealth Management', 'Veterinary', 'Tourism',
#        'Consumer Electronics', 'Analytics', 'Facilities Support Services',
#        'Medical', 'Music Streaming', 'Retail', 'Business Development',
#        'Human Resources', 'Customer Service', 'Training',
#        'Dietary Supplements', 'Collaboration', 'Nanotechnology',
#        'File Sharing', 'Crowdfunding', 'Catering', 'Computer', 'Android',
#        'Delivery', 'Environmental Consulting', 'Commercial Real Estate',
#        'Delivery Service', 'Basketball', 'Fraud Detection',
#        'Cryptocurrency', 'Wedding', 'Crowdsourcing', 'Farming',
#        'Business Travel', 'Career Planning', 'Medical Device',
#        'Alternative Medicine', 'Dental', 'CleanTech', 'Marketing',
#        'Commercial', 'Continuing Education', 'Smart Cities',
#        'Social Media', 'Biopharma', 'Child Care', 'Health Insurance',
#        'Gaming', 'Search Engine', 'Battery', 'Cosmetics', 'eSports',
#        'Reading Apps', 'Electric Vehicle', 'Packaging Services',
#        'Last Mile Transportation', 'Cooking', 'FinTech', 'Online Games',
#        'Online Portals', 'Music', 'News', 'Industrial', 'Dating',
#        'Fantasy Sports', 'Eyewear', 'Ecommerce', 'Edtech',
#        'Interior design', 'AgriTech', 'Technology', 'SaaS', 'AI & Tech',
#        'E-commerce', 'E-commerce & AR', 'Fintech', 'HR tech', 'Food tech',
#        'Health', 'Healthcare', 'Safety tech', 'Pharmaceutical',
#        'Insurance technology', 'AI', 'Foodtech', 'Food', 'IoT',
#        'E-marketplace', 'Robotics & AI', 'Food & Nutrition', 'E-Sports',
#        'Jewellery', 'B2B Supply Chain', 'Games', 'Food & tech',
#        'Accomodation', 'Automotive tech', 'Legal tech', 'Mutual Funds',
#        'Cybersecurity', 'Automobile', 'Healthtech', 'Yoga & wellness',
#        'Virtual Banking', 'Transport & Rentals',
#        'Marketing & Customer loyalty', 'Infratech',
#        'Automobile & Technology', 'Hygiene management', 'Escrow',
#        'Networking platform', 'Food & Bevarages', 'HealthTech',
#        'Fashion startup', 'Food Industry', 'Virtual auditing startup',
#        'Work fulfillment', 'AI startup', 'Telecommunication',
#        'Tech Startup', 'Medtech', 'Tyre management', 'Cloud company',
#        'Software company', 'Venture capitalist', 'Renewable player',
#        'IoT startup', 'SaaS startup', 'Aero company', 'Marketing company',
#        'Retail startup', 'Co-working Startup', 'Finance company',
#        'Tech company', 'Solar Monitoring Company',
#        'Video sharing platform', 'Gaming startup',
#        'Video streaming platform', 'Consumer appliances',
#        'Blockchain startup', 'Conversational AI platform', 'Real Estate',
#        'SaaS platform', 'AI platform', 'Fusion beverages', 'HR Tech',
#        'Job portal', 'Dairy startup', 'Content management', 'Spacetech',
#        'Trading platform', 'AI Company', 'Photonics startup',
#        'Entertainment', 'Scanning app', 'Skincare startup',
#        'Food and Beverages', 'Biotechnology company', 'FoodTech',
#        'Proptech', 'Fitness startup', 'PaaS startup', 'Beverages',
#        'Automobiles', 'Deeptech', 'EV startup', 'AR/VR startup',
#        'Recruitment startup', 'QSR startup', 'Video platform',
#        'Fertility tech', 'Luxury car startup', 'FM', 'Nutrition sector',
#        'Tech platform', 'Video', 'Retail Tech', 'HeathTech',
#        'Sles and marketing', 'LegalTech', 'Car Service',
#        'Bike marketplace', 'Agri tech', 'Reatil startup', 'AR platform',
#        'Content marketplace', 'Interior Design', 'Rental space',
#        'Soil-Tech', 'Ayurveda tech', 'Packaging solution startup',
#        'Cleantech', 'Sanitation solutions', 'HealthCare', 'Home Design',
#        'InsureTech', 'AI Startup', 'Solar solution', 'Jewellery startup',
#        'Multinational conglomerate company', 'Deeptech startup',
#        'Social Network', 'Publication', 'Tech', 'Venture capital',
#        'Entreprenurship', 'Food devlivery', 'Warehouse',
#        'Online financial service', 'Eyeglasses', 'Battery design',
#        'Online credit management startup', 'Beverage', 'TravelTech',
#        'Startup laboratory', 'Personal care startup',
#        'Customer service company', 'SaaS\xa0\xa0startup',
#        'Marketing startup', 'Service industry', 'Social media',
#        'AR startup', 'HR Tech startup', 'Automotive Startup',
#        'Food Startup', 'EdTech Startup', 'Car Trade', 'EdtTech',
#        'AI Platform', 'Automation', 'Solar SaaS', 'WL & RAC protection',
#        'Social commerce', 'Home interior services', 'Agritech startup',
#        'API platform', 'Deep Tech', 'Electricity', 'Automotive company',
#        'FMCG', 'Insurance Tech', 'Video personalization',
#        'Software Company', 'Biomaterial startup', 'IT', 'Craft Beer',
#        'Investment', 'Linguistic Spiritual', 'Construction',
#        'Battery manufacturer', 'Nano Distribution Network', 'AI health',
#        'Dating app', 'Media', 'Healthcare/Edtech', 'Social Commerce',
#        'Agritech/Commerce', 'Mobility tech', 'Social e-commerce',
#        'Food & Logistics', 'SpaceTech', 'Nutrition Tech', 'HR',
#        'Agritech', 'AR/VR', 'Appliance', 'Mental Health',
#        'Solar Solution', 'B2B marketplace', 'Fashion Tech',
#        'Nutrition tech', 'Health & Wellness', 'Cloud Kitchen',
#        'IoT/Automobile', 'Eye Wear', 'Digital tech', 'Data Intelligence',
#        'Co-living', 'Food & Beverages', 'Defense tech',
#        'Construction tech', 'Nutrition', 'Coworking', 'Micro-mobiity',
#        'Auto-tech', 'Robotics', 'Logitech', 'Med Tech', 'Life sciences',
#        'Retail Aggregator', 'Deep Tech AI', 'Biotech', 'HrTech',
#        'Mobility/Transport', 'AI & Debt', 'SaaS/Edtech', 'Transport',
#        'Co-working', 'Insurtech', 'Legal', 'EV', 'Supply chain, Agritech',
#        'Pharma', 'Foodtech & Logistics', 'Housing', 'Data Analytics',
#        'Investment Tech', 'Dairy', 'Beauty & wellness', 'Travel & SaaS',
#        'Tourism & EV', 'Media Tech', 'Location Analytics', 'E store',
#        'Data Science', 'Health and Fitness', 'Interior & decor',
#        'eMobility', 'Automation tech', 'Media & Networking', 'E-market',
#        'AI & Data science', 'Travel tech', 'Automotive and Rentals',
#        'E-tail', 'AI & Media', 'Machine Learning', 'Content Marktplace',
#        'Visual Media', 'Hygiene', 'VR & SaaS', 'Sales & Services',
#        'AI & Deep learning', 'Housing & Rentals', 'Estore', 'E tailor',
#        'E-mobility', 'Ad-tech', 'Neo-banking', 'Transport Automation',
#        'Techonology', 'AI Robotics', 'Preschool Daycare', 'Food diet',
#        'B2B Agritech', 'E-connect', 'Tech hub', 'Consultancy', 'Pharmacy',
#        'Deisgning', 'Taxation', 'Automobile Technology', 'B2B E-commerce',
#        'Home services', 'B2B service', 'Helathcare', 'Electronics',
#        'IT startup', 'Aeorspace', 'Oil and Energy', 'Telecommuncation',
#        'Milk startup', 'AI Chatbot', 'Food delivery', 'Fantasy sports',
#        'Video communication', 'Skill development', 'Recruitment',
#        'Computer Games', 'Apparel & Fashion', 'Logistics & Supply Chain',
#        'SportsTech', 'HRTech', 'Wine & Spirits',
#        'Mechanical & Industrial Engineering', 'Spiritual', 'Lifestyle',
#        'Computer software', 'Tech startup', 'Digital mortgage',
#        'Information Technology & Services', 'Furniture', 'Healtcare',
#        'Tobacco', 'Insuretech', 'MLOps platform', 'Venture Capital',
#        'Pet care', 'Drone', 'Wholesale', 'E-learning',
#        'Consumer Services', 'Venture Capital & Private Equity',
#        'Health, Wellness & Fitness', 'OTT', 'Education Management',
#        'Computer Software', 'Software Startup',
#        'Computer & Network Security', 'Capital Markets', 'Social network',
#        'Hospital & Health Care', 'Pharmaceuticals', 'Mobility',
#        'Digital platform', 'B2B Ecommerce', 'Online Media',
#        'Mobile Games', 'Food Production', 'Podcast', 'Content publishing',
#        'Water purification', 'Content commerce', 'Innovation Management',
#        'Celebrity Engagement', 'Personal Care', 'Cannabis startup',
#        'Blogging', 'BioTechnology', 'B2B Marketplace', 'Health care',
#        'Social audio', 'Fashion and lifestyle', 'Delivery service',
#        'B2B Manufacturing', 'Solar', 'TaaS startup',
#        'Manufacturing startup', 'Vehicle repair startup', 'Advisory firm',
#        'Legaltech', 'Pollution control equiptment', 'Fashion & Lifestyle',
#        'D2C', 'Environmental Services', 'Merchandise',
#        'Facilities Services', 'Marketing & Advertising', 'D2C Business',
#        'NFT Marketplace', 'Consumer software', 'Social community',
#        'Fishery', 'Renewables & Environment', 'Online storytelling',
#        'Aviation', 'IT company', 'Environmental service',
#        'Job discovery platform', 'D2C Fashion', 'Heathcare', 'CRM',
#        'D2C startup', 'Innovation management', 'Community platform',
#        'Networking', 'Consumer service', 'Consumer goods', 'MarTech',
#        'Advertisement', 'Content creation', 'Augmented reality',
#        'Bike Rental', 'Beauty products', 'FemTech', 'Cultural',
#        'Supply chain platform', 'Social platform', 'Real estate',
#        'AI company', 'Sports startup', 'Matrimony', 'Crypto', 'Clothing',
#        'IoT platform', 'Commerce', 'Defense & Space',
#        'Business Supplies & Equipment', 'NFT', 'Oil & Energy',
#        'Company-as-a-Service', 'Textiles',
#        'Professional Training & Coaching', 'Maritime',
#        'Housing Marketplace', 'Furniture Rental', 'Telecommunications',
#        'Equity Management', 'Cloud kitchen', 'Community',
#        'Higher Education', 'Mechanical Or Industrial Engineering',
#        'D2C jewellery', 'Sales and Distribution',
#        'Translation & Localization', 'Investment Banking', 'Femtech',
#        'sports', 'Foootwear', 'Legal Services', 'Arts & Crafts',
#        'Investment Management', 'Management Consulting', 'B2B startup',
#        'Design', 'B2B Travel', 'Product studio', 'Aviation & Aerospace',
#        'Staffing & Recruiting'], dtype=object)

# %%
startup_data['Sector']=startup_data['Sector'].replace('Edtech','EdTech')

# %%
pd.set_option('display.float_format','{:.2f}'.format)

# %% [markdown]
# ## Univariate Analysis
#
# ‘Univariate analysis’ is the analysis of one variable at a time. This analysis might be done by computing some statistical indicators and by plotting some charts respectively using the pandas dataframe's method `.describe()` and one of the plotting libraries like  [Seaborn](https://seaborn.pydata.org/), [Matplotlib](https://matplotlib.org/), [Plotly](https://seaborn.pydata.org/), etc.
#
# Please, read [this article](https://towardsdatascience.com/8-seaborn-plots-for-univariate-exploratory-data-analysis-eda-in-python-9d280b6fe67f) to know more about the charts.

# %% [markdown]
# ### Research Questions
#
#
# Which Industry received the highest amount of funding?
#
# Which industry received the lowest amount of funding?
#
# Which location recorded the highest amount of funding received?
#
# What is the average amount of funding received in top ten sectors?
#
# How many companies received funded in each year?
#
# Which company received the highest amount of funds?
#
# Which company received the lowest amount of funds ?

# %% [markdown]
# ### Which Industry received the highest amount of funding?

# %%
## Group by industries and sum amounts
industry=startup_data.groupby('Sector').sum(numeric_only=True).reset_index()
industry
# Out:
#                  Sector    Amount($)
# 0           3D Printing         0.00
# 1                    AI 116346500.00
# 2     AI & Data science   8000000.00
# 3             AI & Debt         0.00
# 4    AI & Deep learning         0.00
# ..                  ...          ...
# 585    Work fulfillment    500000.00
# 586     Yoga & wellness   2800000.00
# 587           eMobility   1000000.00
# 588             eSports    584000.00
# 589              sports   2400000.00
#
# [590 rows x 2 columns]

# %%
# sort amount in decesnding order
industry.sort_values(['Amount($)'], ascending = False, inplace=True)
#industry['Amount($)']=industry['Amount($)'].apply(lambda x: float('{:.2f}'.format(x)))

# %%
## getting top 10 using head()
top_10_industry=industry.head(10)
top_10_industry
# Out:
#                                  Sector       Amount($)
# 265                             FinTech 153863510000.00
# 479                              Retail  70542380000.00
# 225                              EdTech   6382129230.00
# 535                        Tech company   3022700000.00
# 214                          E-commerce   2879052000.00
# 55                           Automotive   2400388722.00
# 423  Multinational conglomerate company   2200000000.00
# 268                  Financial Services   2081802500.00
# 279                       Food Delivery   1873076000.00
# 332                         Hospitality   1735561000.00

# %%
plt.title('Top 10 Sectors that received the highest amount of funding')
sns.barplot(y=top_10_industry['Sector'],x=top_10_industry['Amount($)'],palette='Greens_d')
plt.xlabel('Amount of Funding Received')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# **Observations**
#
# The setor **Fintech** receive the highest funding in the Indian Ecosystem whith an amount of $ 153863510000.00.
#
# Followed  by Retail with $ 70542380000.00
#
# And EdTech with $ 6382129230.00

# %% [markdown]
# ### Which industry received the lowest amount of funding?

# %%
## using .tail() to get industries with least funding
lowest =industry.tail(100)
lowest
# Out:
#                      Sector  Amount($)
# 81        Beauty & wellness  150000.00
# 580       Wealth Management  150000.00
# 372  Job discovery platform  140000.00
# 439          Nutrition tech  133000.00
# 86              Bike Rental  125000.00
# ..                      ...        ...
# 500            Smart Cities       0.00
# 154        Content commerce       0.00
# 498        Skincare startup       0.00
# 425         Music Streaming       0.00
# 0               3D Printing       0.00
#
# [100 rows x 2 columns]

# %%
#get sectors with amounts greater than 0
lowest_funding=lowest[lowest['Amount($)']>0.0]
lowest_funding
# Out:
#                        Sector  Amount($)
# 81          Beauty & wellness  150000.00
# 580         Wealth Management  150000.00
# 372    Job discovery platform  140000.00
# 439            Nutrition tech  133000.00
# 86                Bike Rental  125000.00
# 575  Virtual auditing startup  120000.00
# 187                Dating app  110000.00
# 302                Government  100000.00
# 377                Legal tech  100000.00
# 167              Credit Cards  100000.00
# 441              Oil & Energy  100000.00
# 213                  E-Sports  100000.00
# 357          Interior & decor  100000.00
# 416              Milk startup  100000.00
# 578                 Warehouse   54000.00
# 202         Digital Marketing    1460.00

# %%
#plot
plt.title('Industries received the lowest amount of funding')
#plt.barh(top_10_idsty.index,top_10_idsty['Amount($)'], color='blue')
sns.barplot(y=lowest_funding['Sector'''],x=lowest_funding['Amount($)'],palette='Blues_d')
plt.xlabel('Amount of Funding Received')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# These Sectors did not receive enough funding from investors in the Indian Ecosystem.

# %% [markdown]
# ### Which location recorded the highest amount of funding received?

# %%
HQ=startup_data.groupby('HeadQuarter').sum(numeric_only=True).reset_index()

# %%
#sort amount in descending order
HQ.sort_values(['Amount($)'], ascending = False, inplace=True)
HQ
# Out:
#            HeadQuarter       Amount($)
# 74              Mumbai 231530895700.00
# 9            Bangalore  24515424404.00
# 41            Gurugram   5704667000.00
# 78           New Delhi   3423246040.00
# 21          California   3078300000.00
# ..                 ...             ...
# 73   Mountain View, CA            0.00
# 72              Mohali            0.00
# 69           Mangalore            0.00
# 52           Jharkhand            0.00
# 129              Worli            0.00
#
# [130 rows x 2 columns]

# %%
top_5_HQ=HQ.head()
top_5_HQ
# Out:
#    HeadQuarter       Amount($)
# 74      Mumbai 231530895700.00
# 9    Bangalore  24515424404.00
# 41    Gurugram   5704667000.00
# 78   New Delhi   3423246040.00
# 21  California   3078300000.00

# %%
plt.title('Top 5 HeadQuarters in funding')
sns.barplot(y=top_5_HQ['HeadQuarter'],x=top_5_HQ['Amount($)'],palette='Reds_d')
plt.ylabel('HQ')
plt.xlabel('Amount of Funding Received')
plt.show()

# %% [markdown]
# ###  What is the average amount of funding received in top ten sectors?

# %%
# avreage o
AVG_industry=startup_data.query("Sector==['FinTech','Retail','EdTech','Tech company','E-commerce','Automotive','Multinational conglomerate company','Food Delivery''Hospitality']").groupby('Sector').mean(numeric_only=True).reset_index()

# %%
AVG_industry.sort_values(['Amount($)'], ascending = False, inplace=True)

# %%
AVG_industry
# Out:
#                                Sector     Amount($)
# 5                              Retail 2939265833.33
# 4  Multinational conglomerate company 2200000000.00
# 3                             FinTech  999113701.30
# 6                        Tech company  377837500.00
# 0                          Automotive   52182363.52
# 1                          E-commerce   42970925.37
# 2                              EdTech   35456273.50

# %%
top_AV_SEC=AVG_industry

# %%
plt.title('Top 10 Average Industry in funding')
sns.barplot(y=top_AV_SEC['Sector'],x=top_AV_SEC['Amount($)'],palette='Greens_d')
plt.xlabel('Average Amount of Funding Received')
plt.ylabel('Sector')
plt.show()

# %% [markdown]
# ### How many companies received funding in each year?

# %%
year =startup_data.groupby(['Funding Year']).count().reset_index()
year
# Out:
#   Funding Year  Company/Brand  Sector  Stage  Amount($)  HeadQuarter  \
# 0         2018            526     526    526        378          526
# 1         2019             89      89     89         77           89
# 2         2020           1055    1055   1055        807         1055
# 3         2021           1206    1206   1206       1066         1206
#
#    What it does  Founded  Founders  Investor
# 0           526      526       526       526
# 1            89       89        89        89
# 2          1055     1055      1055      1055
# 3          1206     1206      1206      1206

# %%
#plt.xlabel('Year')
#plt.ylabel('Number of companies r')
plt.title('Number of companies received funding in each year')
ax=sns.lineplot(y=year['Company/Brand'],x=year['Funding Year'])
ax.set(xlabel='Year',ylabel='Number of companies')
plt.show()

# %% [markdown]
# **2021(1206)** had most companies receiving funding, followed by **2020(1055)** and **2018(526)**, with **2019(89)** at the least

# %% [markdown]
# ### What is the total amount received funding each year

# %%
amtby_year=startup_data.groupby(['Funding Year']).sum(numeric_only=True).reset_index()
amtby_year
# Out:
#   Funding Year       Amount($)
# 0         2018   6641773177.00
# 1         2019   3336433200.00
# 2         2020  91516935104.00
# 3         2021 179850751000.00

# %%
plt.title('Total Amount($) received funding each year')
ax=sns.barplot(y=amtby_year['Amount($)'],x=amtby_year['Funding Year'],palette='Greens_d')
ax.set(xlabel='Year',ylabel='Amount($)')
plt.show()

# %% [markdown]
# **2021(1206)** had most companies receiving funding, followed by **2020(1055)** and **2018(526)**, with **2019(89)** at the least

# %% [markdown]
# ### Which company received the highest amount of funds?

# %%
companies=startup_data.groupby('Company/Brand').sum(numeric_only=True).reset_index()
companies
# Out:
#                Company/Brand    Amount($)
# 0                        &ME         0.00
# 1                    1Bridge   2500000.00
# 2                     1Crowd   3500000.00
# 3           1K Kirana Bazaar   7000000.00
# 4                        1MG   9900000.00
# ...                      ...          ...
# 2209              saarthi.ai         0.00
# 2210                   srJna         0.00
# 2211                   truMe    140000.00
# 2212  uFony Services Pvt ltd         0.00
# 2213                  upGrad 145000000.00
#
# [2214 rows x 2 columns]

# %%
companies.sort_values(['Amount($)'], ascending = False, inplace=True)

# %%
companies
# Out:
#                      Company/Brand       Amount($)
# 70                 Alteria Capital 150000000000.00
# 1556  Reliance Retail Ventures Ltd  70000000000.00
# 1726                     Snowflake   3000000000.00
# 1553                      Reliance   2200000000.00
# 1818                        Swiggy   1956000000.00
# ...                            ...             ...
# 1352                       Orbo.ai            0.00
# 1365                  PadCare Labs            0.00
# 1368                  PakkaProfile            0.00
# 1379                   Pathfndr.io            0.00
# 0                              &ME            0.00
#
# [2214 rows x 2 columns]

# %%
top_5_companies=companies.head()

# %%
##plt.title('Total Amount($) received funding each year')
ax=sns.barplot(y=top_5_companies['Company/Brand'],x=top_5_companies['Amount($)'],palette='Greens_d')
ax.set(xlabel='Amount($)',ylabel='Companies')
plt.title('Top 5 companies with the highest funding.')
plt.show()

# %% [markdown]
# ## Multivariate Analysis
#
# Multivariate analysis’ is the analysis of more than one variable and aims to study the relationships among them. This analysis might be done by computing some statistical indicators like the `correlation` and by plotting some charts.
#
# Please, read [this article](https://towardsdatascience.com/10-must-know-seaborn-functions-for-multivariate-data-analysis-in-python-7ba94847b117) to know more about the charts.

# %% [markdown]
# ### What id the trend of funding received by top 5 Sectors from 2018 to 2021

# %%
HQ_sec=startup_data.query("Sector==['EdTech','FinTech','Retail', 'Tech company','E-commerce']").groupby(['Funding Year','Sector'])['Amount($)'].sum(numeric_only=True).reset_index()
#HQ_sec.sort_values(['Funding Year'], ascending = True, inplace=True)
HQ_sec
# Out:
#    Funding Year        Sector       Amount($)
# 0          2018        EdTech    591914500.00
# 1          2018       FinTech     17600000.00
# 2          2018        Retail     37680000.00
# 3          2019    E-commerce    288000000.00
# 4          2019        EdTech    736182700.00
# 5          2020    E-commerce   1261607000.00
# 6          2020        EdTech   3112502030.00
# 7          2020       FinTech   1233930000.00
# 8          2020        Retail  70239400000.00
# 9          2020  Tech company   3022700000.00
# 10         2021    E-commerce   1329445000.00
# 11         2021        EdTech   1941530000.00
# 12         2021       FinTech 152611980000.00
# 13         2021        Retail    265300000.00

# %%
sns.barplot(x=HQ_sec['Funding Year'],y=HQ_sec['Amount($)'],hue=HQ_sec['Sector'])
# Out:
# <Axes: xlabel='Funding Year', ylabel='Amount($)'>

# %%
sns.lineplot(x='Funding Year',y='Amount($)',data=HQ_sec,hue='Sector')
plt.title('Trend of funding received by top 5 Sectors from 2018 to 2021')
# Out:
# Text(0.5, 1.0, 'Trend of funding received by top 5 Sectors from 2018 to 2021')

# %% [markdown]
# ### What id the trend of funding reveived by top 5 HeadQuarters from 2018 to 2021

# %%
top_5_HQ_visual=startup_data.query("HeadQuarter==['Mumbai','Bangalore','Gurugram', 'New Delhi','California']").groupby(['HeadQuarter','Funding Year']).sum(numeric_only=True).reset_index()
top_5_HQ_visual.sort_values(['Funding Year'], ascending = True, inplace=True)
top_5_HQ_visual
# Out:
#    HeadQuarter Funding Year       Amount($)
# 0    Bangalore         2018   2304840046.00
# 8       Mumbai         2018   1842373200.00
# 12   New Delhi         2018    464194040.00
# 1    Bangalore         2019    824900000.00
# 5     Gurugram         2019    785200000.00
# 9       Mumbai         2019    372500000.00
# 13   New Delhi         2019      5000000.00
# 2    Bangalore         2020   5644849358.00
# 4   California         2020   3078300000.00
# 6     Gurugram         2020    580582000.00
# 10      Mumbai         2020  75173472500.00
# 14   New Delhi         2020    890632000.00
# 3    Bangalore         2021  15740835000.00
# 7     Gurugram         2021   4338885000.00
# 11      Mumbai         2021 154142550000.00
# 15   New Delhi         2021   2063420000.00

# %%
sns.barplot(x=top_5_HQ_visual['Funding Year'],y=top_5_HQ_visual['Amount($)'],hue=top_5_HQ_visual['HeadQuarter'])
# Out:
# <Axes: xlabel='Funding Year', ylabel='Amount($)'>

# %%
sns.lineplot(x='Funding Year',y='Amount($)',data=top_5_HQ_visual,hue='HeadQuarter')
plt.show()

# %% [markdown]
# ## Missing/NaN Values
# Handle the missing/NaN values using the Scikif-learn SimpleImputer

# %%
# Code Here

# %% [markdown]
# ## Scaling
# Scale the numeric features using the Scikif-learn StandardScaler, MinMaxScaler, or another Scaler.

# %%
# Code here

# %% [markdown]
# ## Encoding
# Encode the categorical features using the Scikif-learn OneHotEncoder.

# %%
# Code here
startup_data.to_csv('startup.csv')
